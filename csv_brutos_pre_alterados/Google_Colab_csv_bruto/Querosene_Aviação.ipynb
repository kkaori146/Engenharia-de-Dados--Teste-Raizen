# %% [markdown]
# ## Instalação do Pandera

# %%
pip install pandera
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandera
#   Downloading pandera-0.9.0-py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 5.3 MB/s
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandera) (4.1.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.21.6)
# Collecting typing-inspect>=0.6.0
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from pandera) (1.9.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (21.3)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.3.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from pandera) (6.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->pandera) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->pandera) (1.15.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pandera
# Successfully installed mypy-extensions-0.4.3 pandera-0.9.0 typing-inspect-0.8.0

# %% [markdown]
# ##IMPORTAÇÃO DAS BIBLIOTECAS PANDAS E PANDERA

# %%
import pandas as pd
import pandera as pa

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %% [markdown]
# ##ACRE

# %%
# Conector

dfac = pd.read_csv('/content/AC_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfac_backup = dfac.copy()

# %%
# Visualização da Tabela

dfac
# Out:
#           Mês     2000     2001     2002     2003     2004     2005     2006  \
# 0     Janeiro    1.155    1.528  765.000  978.000  830.000  885.000  863.000
# 1   Fevereiro    1.251    1.021  715.000  808.000  760.000  965.000  736.000
# 2       Março  813.000    1.453  652.000  785.000  931.000    1.032  863.000
# 3       Abril  702.000    1.180  798.000    1.195  914.000  876.000  775.000
# 4        Maio  964.000    1.062    1.714    1.096  931.000  905.000  822.000
# 5       Junho  938.000    1.022  739.000    1.139    1.014  918.000  639.000
# 6       Julho    1.119    1.041  709.000    1.034    1.063  872.000  752.000
# 7      Agosto    1.099    1.016  634.000  780.000    1.127  584.000  692.000
# 8    Setembro    1.047  652.000  773.000  961.000  904.000  547.000  675.000
# 9     Outubro    1.061  814.000  884.000  861.000  904.000  631.000    1.021
# 10   Novembro    1.418  968.000  800.000  789.000  879.000  658.000    1.429
# 11   Dezembro    1.405  791.000  965.000    1.044  877.000  849.000    1.338
#
#        2007     2008     2009     2010   2011   2012     2013     2014  \
# 0     1.431    1.119    1.120    1.151  1.493  1.400    1.185    1.142
# 1     1.138    1.087    1.003    1.180  1.301  1.027    1.018  967.000
# 2     1.191    1.127    1.364    1.336  1.433  1.098    1.030    1.369
# 3     1.116    1.074    1.336    1.089  1.438  1.106  936.000    1.364
# 4     1.225    1.036    1.247    1.185  1.394  1.008    1.074  895.000
# 5     1.047    1.023  980.000    1.076  1.244  1.102  963.000  810.000
# 6     1.206    1.238  987.000    1.025  1.325  1.248    1.032  973.000
# 7     1.036  971.000    1.015  948.000  1.396  1.216  895.000    1.007
# 8   864.000    1.060    1.015  991.000  1.365  1.092  876.000    1.014
# 9     1.045    1.081    1.040    1.342  1.399  1.316  987.000    1.053
# 10  985.000  992.000    1.214    1.232  1.410  1.321    1.069  906.000
# 11    1.275    1.133    1.225    1.501  1.539  1.208    1.146  992.000
#
#        2015     2016     2017     2018     2019     2020     2021     2022
# 0     1.051  939.000    1.009    1.059    1.070    1.325    1.150    1.015
# 1   946.000  762.000  827.000  932.000    1.018    1.302    1.018  638.000
# 2     1.024  741.000  963.000    1.031  979.000  907.000  807.000    1.222
# 3   849.000  671.000  888.000    1.124    1.021  103.000  572.000  727.000
# 4   851.000  745.000  871.000    1.175  988.000  143.000  637.000  671.000
# 5   723.000  686.000  873.000    1.080    1.043  134.000  698.000  595.000
# 6   778.000  703.000    1.003    1.346    1.086  347.000  715.000      NaN
# 7   733.000  697.000  995.000    1.305    1.153  443.000  819.000      NaN
# 8   701.000  724.000  942.000  949.000    1.045  574.000  784.000      NaN
# 9   740.000  723.000    1.127    1.012    1.157  720.000  983.000      NaN
# 10  774.000  857.000    1.073    1.031    1.250    1.043    1.044      NaN
# 11  771.000    1.003    1.068    1.199    1.206    1.175    1.226      NaN

# %%
# Replace do Mês para numérico

dfac["Mês"].replace("Janeiro", "01", inplace=True)
dfac["Mês"].replace("Fevereiro", "02", inplace=True)
dfac["Mês"].replace("Março", "03", inplace=True)
dfac["Mês"].replace("Abril", "04", inplace=True)
dfac["Mês"].replace("Maio", "05", inplace=True)
dfac["Mês"].replace("Junho", "06", inplace=True)
dfac["Mês"].replace("Julho", "07", inplace=True)
dfac["Mês"].replace("Agosto", "08", inplace=True)
dfac["Mês"].replace("Setembro", "09", inplace=True)
dfac["Mês"].replace("Outubro", "10", inplace=True)
dfac["Mês"].replace("Novembro", "11", inplace=True)
dfac["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfac['uf']='AC'
dfac['produto']='Querosene de Aviação'
dfac['unid']='m3'
dfac['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfac.reset_index(inplace=True)

# %%
dfac=dfac.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfac

# %%
# Concatenando as colunas ano e Mês

dfac['ano_mês'] = dfac[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfac.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfac =dfac[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfac.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfac.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfac

# %%
# Verificando os tipos

dfac.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfac)

# %%
dfac_pandas = dfac.copy()

# %% [markdown]
# ##ALAGOAS

# %%
# Conector

dfal = pd.read_csv('/content/AL_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfal_backup = dfal.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfal

# %%
# Replace do Mês para numérico

dfal["Mês"].replace("Janeiro", "01", inplace=True)
dfal["Mês"].replace("Fevereiro", "02", inplace=True)
dfal["Mês"].replace("Março", "03", inplace=True)
dfal["Mês"].replace("Abril", "04", inplace=True)
dfal["Mês"].replace("Maio", "05", inplace=True)
dfal["Mês"].replace("Junho", "06", inplace=True)
dfal["Mês"].replace("Julho", "07", inplace=True)
dfal["Mês"].replace("Agosto", "08", inplace=True)
dfal["Mês"].replace("Setembro", "09", inplace=True)
dfal["Mês"].replace("Outubro", "10", inplace=True)
dfal["Mês"].replace("Novembro", "11", inplace=True)
dfal["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfal['uf']='AL'
dfal['produto']='Querosene de Aviação'
dfal['unid']='m3'
dfal['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfal.reset_index(inplace=True)

# %%
dfal=dfal.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfal

# %%
# Concatenando as colunas ano e Mês

dfal['ano_mês'] = dfal[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfal.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfal =dfal[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfac.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfal.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfal

# %%
# Verificando os tipos

dfal.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfal)

# %%
dfal_pandas = dfal.copy()

# %% [markdown]
# ##AMAZONAS

# %%
# Conector

dfam = pd.read_csv('/content/AM_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfam_backup = dfam.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfam

# %%
# Replace do Mês para numérico

dfam["Mês"].replace("Janeiro", "01", inplace=True)
dfam["Mês"].replace("Fevereiro", "02", inplace=True)
dfam["Mês"].replace("Março", "03", inplace=True)
dfam["Mês"].replace("Abril", "04", inplace=True)
dfam["Mês"].replace("Maio", "05", inplace=True)
dfam["Mês"].replace("Junho", "06", inplace=True)
dfam["Mês"].replace("Julho", "07", inplace=True)
dfam["Mês"].replace("Agosto", "08", inplace=True)
dfam["Mês"].replace("Setembro", "09", inplace=True)
dfam["Mês"].replace("Outubro", "10", inplace=True)
dfam["Mês"].replace("Novembro", "11", inplace=True)
dfam["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfam['uf']='AM'
dfam['produto']='Querosene de Aviação'
dfam['unid']='m3'
dfam['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfam.reset_index(inplace=True)

# %%
dfam=dfam.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfam

# %%
# Concatenando as colunas ano e Mês

dfam['ano_mês'] = dfam[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfam.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfam =dfam[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfam.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfam.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfam

# %%
# Verificando os tipos

dfam.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfam)

# %%
dfam_pandas = dfam.copy()

# %% [markdown]
# ##AMAPÁ

# %%
# Conector

dfap = pd.read_csv('/content/AP_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfap_backup = dfap.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfap

# %%
# Replace do Mês para numérico

dfap["Mês"].replace("Janeiro", "01", inplace=True)
dfap["Mês"].replace("Fevereiro", "02", inplace=True)
dfap["Mês"].replace("Março", "03", inplace=True)
dfap["Mês"].replace("Abril", "04", inplace=True)
dfap["Mês"].replace("Maio", "05", inplace=True)
dfap["Mês"].replace("Junho", "06", inplace=True)
dfap["Mês"].replace("Julho", "07", inplace=True)
dfap["Mês"].replace("Agosto", "08", inplace=True)
dfap["Mês"].replace("Setembro", "09", inplace=True)
dfap["Mês"].replace("Outubro", "10", inplace=True)
dfap["Mês"].replace("Novembro", "11", inplace=True)
dfap["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfap['uf']='AP'
dfap['produto']='Querosene de Aviação'
dfap['unid']='m3'
dfap['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfap.reset_index(inplace=True)

# %%
dfap=dfap.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfap

# %%
# Concatenando as colunas ano e Mês

dfap['ano_mês'] = dfap[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfap.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfap =dfap[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfap.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfap.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfap

# %%
# Verificando os tipos

dfap.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfap)

# %%
dfap_pandas = dfap.copy()

# %% [markdown]
# ##BAHIA

# %%
# Conector

dfba = pd.read_csv('/content/BA_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfba_backup = dfba.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfba

# %%
# Replace do Mês para numérico

dfba["Mês"].replace("Janeiro", "01", inplace=True)
dfba["Mês"].replace("Fevereiro", "02", inplace=True)
dfba["Mês"].replace("Março", "03", inplace=True)
dfba["Mês"].replace("Abril", "04", inplace=True)
dfba["Mês"].replace("Maio", "05", inplace=True)
dfba["Mês"].replace("Junho", "06", inplace=True)
dfba["Mês"].replace("Julho", "07", inplace=True)
dfba["Mês"].replace("Agosto", "08", inplace=True)
dfba["Mês"].replace("Setembro", "09", inplace=True)
dfba["Mês"].replace("Outubro", "10", inplace=True)
dfba["Mês"].replace("Novembro", "11", inplace=True)
dfba["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfba['uf']='BA'
dfba['produto']='Querosene de Aviação'
dfba['unid']='m3'
dfba['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfba.reset_index(inplace=True)

# %%
dfba=dfba.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfba

# %%
# Concatenando as colunas ano e Mês

dfba['ano_mês'] = dfba[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfba.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfba =dfba[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfba.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfba.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfba

# %%
# Verificando os tipos

dfba.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfba)

# %%
dfba_pandas = dfba.copy()

# %% [markdown]
# ##CEARÁ

# %%
# Conector

dfce = pd.read_csv('/content/CE_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfce_backup = dfce.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfce

# %%
# Replace do Mês para numérico

dfce["Mês"].replace("Janeiro", "01", inplace=True)
dfce["Mês"].replace("Fevereiro", "02", inplace=True)
dfce["Mês"].replace("Março", "03", inplace=True)
dfce["Mês"].replace("Abril", "04", inplace=True)
dfce["Mês"].replace("Maio", "05", inplace=True)
dfce["Mês"].replace("Junho", "06", inplace=True)
dfce["Mês"].replace("Julho", "07", inplace=True)
dfce["Mês"].replace("Agosto", "08", inplace=True)
dfce["Mês"].replace("Setembro", "09", inplace=True)
dfce["Mês"].replace("Outubro", "10", inplace=True)
dfce["Mês"].replace("Novembro", "11", inplace=True)
dfce["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfce['uf']='CE'
dfce['produto']='Querosene de Aviação'
dfce['unid']='m3'
dfce['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfce.reset_index(inplace=True)

# %%
dfce=dfce.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfce

# %%
# Concatenando as colunas ano e Mês

dfce['ano_mês'] = dfce[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfce.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfce =dfce[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfce.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfce.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfce

# %%
# Verificando os tipos

dfce.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfce)

# %%
dfce_pandas = dfce.copy()

# %% [markdown]
# ##DISTRITO DEFERAL

# %%
# Conector

dfdf = pd.read_csv('/content/DF_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfdf_backup = dfdf.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfdf

# %%
# Replace do Mês para numérico

dfdf["Mês"].replace("Janeiro", "01", inplace=True)
dfdf["Mês"].replace("Fevereiro", "02", inplace=True)
dfdf["Mês"].replace("Março", "03", inplace=True)
dfdf["Mês"].replace("Abril", "04", inplace=True)
dfdf["Mês"].replace("Maio", "05", inplace=True)
dfdf["Mês"].replace("Junho", "06", inplace=True)
dfdf["Mês"].replace("Julho", "07", inplace=True)
dfdf["Mês"].replace("Agosto", "08", inplace=True)
dfdf["Mês"].replace("Setembro", "09", inplace=True)
dfdf["Mês"].replace("Outubro", "10", inplace=True)
dfdf["Mês"].replace("Novembro", "11", inplace=True)
dfdf["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfdf['uf']='DF'
dfdf['produto']='Querosene de Aviação'
dfdf['unid']='m3'
dfdf['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfdf.reset_index(inplace=True)

# %%
dfdf=dfdf.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfdf

# %%
# Concatenando as colunas ano e Mês

dfdf['ano_mês'] = dfdf[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfdf.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfdf =dfdf[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfdf.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfdf.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfdf

# %%
# Verificando os tipos

dfdf.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfdf)

# %%
dfdf_pandas = dfdf.copy()

# %% [markdown]
# ##ES

# %%
# Conector

dfes = pd.read_csv('/content/ES_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfes_backup = dfes.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfes

# %%
# Replace do Mês para numérico

dfes["Mês"].replace("Janeiro", "01", inplace=True)
dfes["Mês"].replace("Fevereiro", "02", inplace=True)
dfes["Mês"].replace("Março", "03", inplace=True)
dfes["Mês"].replace("Abril", "04", inplace=True)
dfes["Mês"].replace("Maio", "05", inplace=True)
dfes["Mês"].replace("Junho", "06", inplace=True)
dfes["Mês"].replace("Julho", "07", inplace=True)
dfes["Mês"].replace("Agosto", "08", inplace=True)
dfes["Mês"].replace("Setembro", "09", inplace=True)
dfes["Mês"].replace("Outubro", "10", inplace=True)
dfes["Mês"].replace("Novembro", "11", inplace=True)
dfes["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfes['uf']='ES'
dfes['produto']='Querosene de Aviação'
dfes['unid']='m3'
dfes['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfes.reset_index(inplace=True)

# %%
dfes=dfes.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfes

# %%
# Concatenando as colunas ano e Mês
dfes['ano_mês'] = dfes[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfes.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfes =dfes[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfes.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
inconsistencias = ["NaN"]
dfes.replace(inconsistencias, pd.NA, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfes

# %%
# Verificando os tipos

dfes.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfes)

# %%
dfes_pandas = dfes.copy()

# %% [markdown]
# ##GOIÁS

# %%
# Conector

dfgo = pd.read_csv('/content/GO_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfgo_backup = dfgo.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfgo

# %%
# Replace do Mês para numérico

dfgo["Mês"].replace("Janeiro", "01", inplace=True)
dfgo["Mês"].replace("Fevereiro", "02", inplace=True)
dfgo["Mês"].replace("Março", "03", inplace=True)
dfgo["Mês"].replace("Abril", "04", inplace=True)
dfgo["Mês"].replace("Maio", "05", inplace=True)
dfgo["Mês"].replace("Junho", "06", inplace=True)
dfgo["Mês"].replace("Julho", "07", inplace=True)
dfgo["Mês"].replace("Agosto", "08", inplace=True)
dfgo["Mês"].replace("Setembro", "09", inplace=True)
dfgo["Mês"].replace("Outubro", "10", inplace=True)
dfgo["Mês"].replace("Novembro", "11", inplace=True)
dfgo["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfgo['uf']='GO'
dfgo['produto']='Querosene de Aviação'
dfgo['unid']='m3'
dfgo['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfgo.reset_index(inplace=True)

# %%
dfgo=dfgo.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfgo

# %%
# Concatenando as colunas ano e Mês

dfgo['ano_mês'] = dfgo[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfgo.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfgo=dfgo[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfgo.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfgo.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfgo

# %%
# Verificando os tipos

dfgo.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfgo)

# %%
dfgo_pandas = dfgo.copy()

# %% [markdown]
# ##MARANHÃO

# %%
# Conector

dfma = pd.read_csv('/content/MA_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfma_backup = dfma.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfma

# %%
# Replace do Mês para numérico

dfma["Mês"].replace("Janeiro", "01", inplace=True)
dfma["Mês"].replace("Fevereiro", "02", inplace=True)
dfma["Mês"].replace("Março", "03", inplace=True)
dfma["Mês"].replace("Abril", "04", inplace=True)
dfma["Mês"].replace("Maio", "05", inplace=True)
dfma["Mês"].replace("Junho", "06", inplace=True)
dfma["Mês"].replace("Julho", "07", inplace=True)
dfma["Mês"].replace("Agosto", "08", inplace=True)
dfma["Mês"].replace("Setembro", "09", inplace=True)
dfma["Mês"].replace("Outubro", "10", inplace=True)
dfma["Mês"].replace("Novembro", "11", inplace=True)
dfma["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfma['uf']='MA'
dfma['produto']='Querosene de Aviação'
dfma['unid']='m3'
dfma['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfma.reset_index(inplace=True)

# %%
dfma=dfma.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfma

# %%
# Concatenando as colunas ano e Mês

dfma['ano_mês'] = dfma[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfma.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfma=dfma[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfma.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfdf.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfma

# %%
# Verificando os tipos

dfma.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfma)

# %%
dfma_pandas = dfma.copy()

# %% [markdown]
# ##MINAS GERAIS

# %%
# Conector

dfmg = pd.read_csv('/content/MG_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfmg_backup = dfmg.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfmg

# %%
# Replace do Mês para numérico

dfmg["Mês"].replace("Janeiro", "01", inplace=True)
dfmg["Mês"].replace("Fevereiro", "02", inplace=True)
dfmg["Mês"].replace("Março", "03", inplace=True)
dfmg["Mês"].replace("Abril", "04", inplace=True)
dfmg["Mês"].replace("Maio", "05", inplace=True)
dfmg["Mês"].replace("Junho", "06", inplace=True)
dfmg["Mês"].replace("Julho", "07", inplace=True)
dfmg["Mês"].replace("Agosto", "08", inplace=True)
dfmg["Mês"].replace("Setembro", "09", inplace=True)
dfmg["Mês"].replace("Outubro", "10", inplace=True)
dfmg["Mês"].replace("Novembro", "11", inplace=True)
dfmg["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfmg['uf']='MG'
dfmg['produto']='Querosene de Aviação'
dfmg['unid']='m3'
dfmg['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfmg.reset_index(inplace=True)

# %%
dfmg=dfmg.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfmg

# %%
# Concatenando as colunas ano e Mês

dfmg['ano_mês'] = dfmg[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfmg.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfmg=dfmg[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfmg.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfdf.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfmg

# %%
# Verificando os tipos

dfmg.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfmg)

# %%
dfmg_pandas = dfmg.copy()

# %% [markdown]
# ##MATO GROSSO DO SUL

# %%
# Conector

dfms = pd.read_csv('/content/MS_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfms_backup = dfms.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfms

# %%
# Replace do Mês para numérico

dfms["Mês"].replace("Janeiro", "01", inplace=True)
dfms["Mês"].replace("Fevereiro", "02", inplace=True)
dfms["Mês"].replace("Março", "03", inplace=True)
dfms["Mês"].replace("Abril", "04", inplace=True)
dfms["Mês"].replace("Maio", "05", inplace=True)
dfms["Mês"].replace("Junho", "06", inplace=True)
dfms["Mês"].replace("Julho", "07", inplace=True)
dfms["Mês"].replace("Agosto", "08", inplace=True)
dfms["Mês"].replace("Setembro", "09", inplace=True)
dfms["Mês"].replace("Outubro", "10", inplace=True)
dfms["Mês"].replace("Novembro", "11", inplace=True)
dfms["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfms['uf']='MS'
dfms['produto']='Querosene de Aviação'
dfms['unid']='m3'
dfms['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfms.reset_index(inplace=True)

# %%
dfms=dfms.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfms

# %%
# Concatenando as colunas ano e Mês

dfms['ano_mês'] = dfms[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfms.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfms=dfms[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfms.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfms.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfms

# %%
# Verificando os tipos

dfms.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfms)

# %%
dfms_pandas = dfms.copy()

# %% [markdown]
# ##MATO GROSO

# %%
# Conector

dfmt = pd.read_csv('/content/MT_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfmt_backup = dfmt.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfmt

# %%
# Replace do Mês para numérico

dfmt["Mês"].replace("Janeiro", "01", inplace=True)
dfmt["Mês"].replace("Fevereiro", "02", inplace=True)
dfmt["Mês"].replace("Março", "03", inplace=True)
dfmt["Mês"].replace("Abril", "04", inplace=True)
dfmt["Mês"].replace("Maio", "05", inplace=True)
dfmt["Mês"].replace("Junho", "06", inplace=True)
dfmt["Mês"].replace("Julho", "07", inplace=True)
dfmt["Mês"].replace("Agosto", "08", inplace=True)
dfmt["Mês"].replace("Setembro", "09", inplace=True)
dfmt["Mês"].replace("Outubro", "10", inplace=True)
dfmt["Mês"].replace("Novembro", "11", inplace=True)
dfmt["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfmt['uf']='MT'
dfmt['produto']='Querosene de Aviação'
dfmt['unid']='m3'
dfmt['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfmt.reset_index(inplace=True)

# %%
dfmt=dfmt.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfmt

# %%
# Concatenando as colunas ano e Mês
dfmt['ano_mês'] = dfmt[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfmt.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfmt=dfmt[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfmt.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfmt.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '-', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfmt

# %%
# Verificando os tipos

dfmt.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfmt)

# %%
dfmt_pandas = dfmt.copy()

# %% [markdown]
# ##PARÁ

# %%
# Conector

dfpa= pd.read_csv('/content/PA_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfpa_backup = dfpa.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfpa

# %%
# Replace do Mês para numérico

dfpa["Mês"].replace("Janeiro", "01", inplace=True)
dfpa["Mês"].replace("Fevereiro", "02", inplace=True)
dfpa["Mês"].replace("Março", "03", inplace=True)
dfpa["Mês"].replace("Abril", "04", inplace=True)
dfpa["Mês"].replace("Maio", "05", inplace=True)
dfpa["Mês"].replace("Junho", "06", inplace=True)
dfpa["Mês"].replace("Julho", "07", inplace=True)
dfpa["Mês"].replace("Agosto", "08", inplace=True)
dfpa["Mês"].replace("Setembro", "09", inplace=True)
dfpa["Mês"].replace("Outubro", "10", inplace=True)
dfpa["Mês"].replace("Novembro", "11", inplace=True)
dfpa["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfpa['uf']='PA'
dfpa['produto']='Querosene de Aviação'
dfpa['unid']='m3'
dfpa['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfpa.reset_index(inplace=True)

# %%
dfpa=dfpa.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfpa

# %%
# Concatenando as colunas ano e Mês

dfpa['ano_mês'] = dfpa[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfpa.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfpa=dfpa[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfpa.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       0
# criado_em    0
# dtype: int64

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfpa.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfpa

# %%
# Verificando os tipos

dfpa.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfpa)

# %%
dfpa_pandas = dfpa.copy()

# %% [markdown]
# ##PARAÍBA

# %%
# Conector

dfpb = pd.read_csv('/content/PB_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfpb_backup = dfpb.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfpb

# %%
# Replace do Mês para numérico

dfpb["Mês"].replace("Janeiro", "01", inplace=True)
dfpb["Mês"].replace("Fevereiro", "02", inplace=True)
dfpb["Mês"].replace("Março", "03", inplace=True)
dfpb["Mês"].replace("Abril", "04", inplace=True)
dfpb["Mês"].replace("Maio", "05", inplace=True)
dfpb["Mês"].replace("Junho", "06", inplace=True)
dfpb["Mês"].replace("Julho", "07", inplace=True)
dfpb["Mês"].replace("Agosto", "08", inplace=True)
dfpb["Mês"].replace("Setembro", "09", inplace=True)
dfpb["Mês"].replace("Outubro", "10", inplace=True)
dfpb["Mês"].replace("Novembro", "11", inplace=True)
dfpb["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfpb['uf']='PB'
dfpb['produto']='Querosene de Aviação'
dfpb['unid']='m3'
dfpb['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfpb.reset_index(inplace=True)

# %%
dfpb=dfpb.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfpb

# %%
# Concatenando as colunas ano e Mês

dfpb['ano_mês'] = dfpb[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfpb.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfpb=dfpb[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfpb.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfpb.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfpb

# %%
# Verificando os tipos

dfpb.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfpb)

# %%
dfpb_pandas = dfpb.copy()

# %% [markdown]
# ##PERNAMBUCO

# %%
# Conector

dfpe = pd.read_csv('/content/PE_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfpe_backup = dfpe.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfpe

# %%
# Replace do Mês para numérico

dfpe["Mês"].replace("Janeiro", "01", inplace=True)
dfpe["Mês"].replace("Fevereiro", "02", inplace=True)
dfpe["Mês"].replace("Março", "03", inplace=True)
dfpe["Mês"].replace("Abril", "04", inplace=True)
dfpe["Mês"].replace("Maio", "05", inplace=True)
dfpe["Mês"].replace("Junho", "06", inplace=True)
dfpe["Mês"].replace("Julho", "07", inplace=True)
dfpe["Mês"].replace("Agosto", "08", inplace=True)
dfpe["Mês"].replace("Setembro", "09", inplace=True)
dfpe["Mês"].replace("Outubro", "10", inplace=True)
dfpe["Mês"].replace("Novembro", "11", inplace=True)
dfpe["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfpe['uf']='PE'
dfpe['produto']='Querosene de Aviação'
dfpe['unid']='m3'
dfpe['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfpe.reset_index(inplace=True)

# %%
dfpe=dfpe.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfpe
# Out:
#     Mês  uf               produto unid   criado_em   ano  volume
# 0    01  PE  Querosene de Aviação   m3  2022-09-10  2000  18.509
# 1    02  PE  Querosene de Aviação   m3  2022-09-10  2000  16.942
# 2    03  PE  Querosene de Aviação   m3  2022-09-10  2000  17.425
# 3    04  PE  Querosene de Aviação   m3  2022-09-10  2000  16.144
# 4    05  PE  Querosene de Aviação   m3  2022-09-10  2000  15.371
# 5    06  PE  Querosene de Aviação   m3  2022-09-10  2000  14.391
# 6    07  PE  Querosene de Aviação   m3  2022-09-10  2000  15.714
# 7    08  PE  Querosene de Aviação   m3  2022-09-10  2000  14.965
# 8    09  PE  Querosene de Aviação   m3  2022-09-10  2000  15.483
# 9    10  PE  Querosene de Aviação   m3  2022-09-10  2000  15.396
# 10   11  PE  Querosene de Aviação   m3  2022-09-10  2000  16.184
# 11   12  PE  Querosene de Aviação   m3  2022-09-10  2000  18.121
# 12   01  PE  Querosene de Aviação   m3  2022-09-10  2001  18.963
# 13   02  PE  Querosene de Aviação   m3  2022-09-10  2001  15.943
# 14   03  PE  Querosene de Aviação   m3  2022-09-10  2001  16.246
# 15   04  PE  Querosene de Aviação   m3  2022-09-10  2001  14.915
# 16   05  PE  Querosene de Aviação   m3  2022-09-10  2001  15.359
# 17   06  PE  Querosene de Aviação   m3  2022-09-10  2001  14.439
# 18   07  PE  Querosene de Aviação   m3  2022-09-10  2001  16.359
# 19   08  PE  Querosene de Aviação   m3  2022-09-10  2001  15.695
# 20   09  PE  Querosene de Aviação   m3  2022-09-10  2001  14.566
# 21   10  PE  Querosene de Aviação   m3  2022-09-10  2001  15.599
# 22   11  PE  Querosene de Aviação   m3  2022-09-10  2001  14.956
# 23   12  PE  Querosene de Aviação   m3  2022-09-10  2001  15.713
# 24   01  PE  Querosene de Aviação   m3  2022-09-10  2002  15.899
# 25   02  PE  Querosene de Aviação   m3  2022-09-10  2002  14.785
# 26   03  PE  Querosene de Aviação   m3  2022-09-10  2002  15.513
# 27   04  PE  Querosene de Aviação   m3  2022-09-10  2002  15.377
# 28   05  PE  Querosene de Aviação   m3  2022-09-10  2002  15.396
# 29   06  PE  Querosene de Aviação   m3  2022-09-10  2002  14.593
# 30   07  PE  Querosene de Aviação   m3  2022-09-10  2002  15.840
# 31   08  PE  Querosene de Aviação   m3  2022-09-10  2002  37.601
# 32   09  PE  Querosene de Aviação   m3  2022-09-10  2002  14.665
# 33   10  PE  Querosene de Aviação   m3  2022-09-10  2002  14.786
# 34   11  PE  Querosene de Aviação   m3  2022-09-10  2002  13.047
# 35   12  PE  Querosene de Aviação   m3  2022-09-10  2002  14.636
# 36   01  PE  Querosene de Aviação   m3  2022-09-10  2003  15.976
# 37   02  PE  Querosene de Aviação   m3  2022-09-10  2003  13.158
# 38   03  PE  Querosene de Aviação   m3  2022-09-10  2003  13.352
# 39   04  PE  Querosene de Aviação   m3  2022-09-10  2003  13.348
# 40   05  PE  Querosene de Aviação   m3  2022-09-10  2003  11.316
# 41   06  PE  Querosene de Aviação   m3  2022-09-10  2003  11.068
# 42   07  PE  Querosene de Aviação   m3  2022-09-10  2003  13.199
# 43   08  PE  Querosene de Aviação   m3  2022-09-10  2003  12.413
# 44   09  PE  Querosene de Aviação   m3  2022-09-10  2003  12.068
# 45   10  PE  Querosene de Aviação   m3  2022-09-10  2003  12.534
# 46   11  PE  Querosene de Aviação   m3  2022-09-10  2003  13.566
# 47   12  PE  Querosene de Aviação   m3  2022-09-10  2003  13.899
# 48   01  PE  Querosene de Aviação   m3  2022-09-10  2004  14.635
# 49   02  PE  Querosene de Aviação   m3  2022-09-10  2004  12.474
# 50   03  PE  Querosene de Aviação   m3  2022-09-10  2004  13.481
# 51   04  PE  Querosene de Aviação   m3  2022-09-10  2004  13.543
# 52   05  PE  Querosene de Aviação   m3  2022-09-10  2004  13.823
# 53   06  PE  Querosene de Aviação   m3  2022-09-10  2004  13.133
# 54   07  PE  Querosene de Aviação   m3  2022-09-10  2004  14.212
# 55   08  PE  Querosene de Aviação   m3  2022-09-10  2004  13.556
# 56   09  PE  Querosene de Aviação   m3  2022-09-10  2004  12.913
# 57   10  PE  Querosene de Aviação   m3  2022-09-10  2004  12.755
# 58   11  PE  Querosene de Aviação   m3  2022-09-10  2004  13.032
# 59   12  PE  Querosene de Aviação   m3  2022-09-10  2004  13.674
# 60   01  PE  Querosene de Aviação   m3  2022-09-10  2005  14.833
# 61   02  PE  Querosene de Aviação   m3  2022-09-10  2005  12.272
# 62   03  PE  Querosene de Aviação   m3  2022-09-10  2005  14.207
# 63   04  PE  Querosene de Aviação   m3  2022-09-10  2005  12.802
# 64   05  PE  Querosene de Aviação   m3  2022-09-10  2005  14.050
# 65   06  PE  Querosene de Aviação   m3  2022-09-10  2005  13.119
# 66   07  PE  Querosene de Aviação   m3  2022-09-10  2005  15.259
# 67   08  PE  Querosene de Aviação   m3  2022-09-10  2005  15.180
# 68   09  PE  Querosene de Aviação   m3  2022-09-10  2005  13.759
# 69   10  PE  Querosene de Aviação   m3  2022-09-10  2005  14.916
# 70   11  PE  Querosene de Aviação   m3  2022-09-10  2005  14.415
# 71   12  PE  Querosene de Aviação   m3  2022-09-10  2005  17.526
# 72   01  PE  Querosene de Aviação   m3  2022-09-10  2006  17.976
# 73   02  PE  Querosene de Aviação   m3  2022-09-10  2006  15.513
# 74   03  PE  Querosene de Aviação   m3  2022-09-10  2006  17.487
# 75   04  PE  Querosene de Aviação   m3  2022-09-10  2006  14.620
# 76   05  PE  Querosene de Aviação   m3  2022-09-10  2006  16.391
# 77   06  PE  Querosene de Aviação   m3  2022-09-10  2006  14.099
# 78   07  PE  Querosene de Aviação   m3  2022-09-10  2006  15.378
# 79   08  PE  Querosene de Aviação   m3  2022-09-10  2006  13.304
# 80   09  PE  Querosene de Aviação   m3  2022-09-10  2006  12.992
# 81   10  PE  Querosene de Aviação   m3  2022-09-10  2006  13.608
# 82   11  PE  Querosene de Aviação   m3  2022-09-10  2006  13.978
# 83   12  PE  Querosene de Aviação   m3  2022-09-10  2006  15.811
# 84   01  PE  Querosene de Aviação   m3  2022-09-10  2007  16.579
# 85   02  PE  Querosene de Aviação   m3  2022-09-10  2007  14.224
# 86   03  PE  Querosene de Aviação   m3  2022-09-10  2007  16.157
# 87   04  PE  Querosene de Aviação   m3  2022-09-10  2007  15.747
# 88   05  PE  Querosene de Aviação   m3  2022-09-10  2007  14.834
# 89   06  PE  Querosene de Aviação   m3  2022-09-10  2007  14.454
# 90   07  PE  Querosene de Aviação   m3  2022-09-10  2007  17.533
# 91   08  PE  Querosene de Aviação   m3  2022-09-10  2007  16.391
# 92   09  PE  Querosene de Aviação   m3  2022-09-10  2007  14.986
# 93   10  PE  Querosene de Aviação   m3  2022-09-10  2007  16.586
# 94   11  PE  Querosene de Aviação   m3  2022-09-10  2007  15.840
# 95   12  PE  Querosene de Aviação   m3  2022-09-10  2007  16.847
# 96   01  PE  Querosene de Aviação   m3  2022-09-10  2008  17.711
# 97   02  PE  Querosene de Aviação   m3  2022-09-10  2008  15.757
# 98   03  PE  Querosene de Aviação   m3  2022-09-10  2008  16.878
# 99   04  PE  Querosene de Aviação   m3  2022-09-10  2008  15.490
# 100  05  PE  Querosene de Aviação   m3  2022-09-10  2008  16.392
# 101  06  PE  Querosene de Aviação   m3  2022-09-10  2008  16.004
# 102  07  PE  Querosene de Aviação   m3  2022-09-10  2008  17.594
# 103  08  PE  Querosene de Aviação   m3  2022-09-10  2008  16.105
# 104  09  PE  Querosene de Aviação   m3  2022-09-10  2008  15.922
# 105  10  PE  Querosene de Aviação   m3  2022-09-10  2008  16.176
# 106  11  PE  Querosene de Aviação   m3  2022-09-10  2008  18.388
# 107  12  PE  Querosene de Aviação   m3  2022-09-10  2008  18.565
# 108  01  PE  Querosene de Aviação   m3  2022-09-10  2009  19.891
# 109  02  PE  Querosene de Aviação   m3  2022-09-10  2009  15.727
# 110  03  PE  Querosene de Aviação   m3  2022-09-10  2009  17.139
# 111  04  PE  Querosene de Aviação   m3  2022-09-10  2009  16.066
# 112  05  PE  Querosene de Aviação   m3  2022-09-10  2009  15.759
# 113  06  PE  Querosene de Aviação   m3  2022-09-10  2009  16.524
# 114  07  PE  Querosene de Aviação   m3  2022-09-10  2009  19.184
# 115  08  PE  Querosene de Aviação   m3  2022-09-10  2009  18.421
# 116  09  PE  Querosene de Aviação   m3  2022-09-10  2009  17.569
# 117  10  PE  Querosene de Aviação   m3  2022-09-10  2009  18.672
# 118  11  PE  Querosene de Aviação   m3  2022-09-10  2009  18.568
# 119  12  PE  Querosene de Aviação   m3  2022-09-10  2009  20.171
# 120  01  PE  Querosene de Aviação   m3  2022-09-10  2010  20.682
# 121  02  PE  Querosene de Aviação   m3  2022-09-10  2010  18.229
# 122  03  PE  Querosene de Aviação   m3  2022-09-10  2010  19.891
# 123  04  PE  Querosene de Aviação   m3  2022-09-10  2010  18.739
# 124  05  PE  Querosene de Aviação   m3  2022-09-10  2010  18.673
# 125  06  PE  Querosene de Aviação   m3  2022-09-10  2010  18.311
# 126  07  PE  Querosene de Aviação   m3  2022-09-10  2010  20.922
# 127  08  PE  Querosene de Aviação   m3  2022-09-10  2010  20.447
# 128  09  PE  Querosene de Aviação   m3  2022-09-10  2010  20.325
# 129  10  PE  Querosene de Aviação   m3  2022-09-10  2010  21.556
# 130  11  PE  Querosene de Aviação   m3  2022-09-10  2010  22.817
# 131  12  PE  Querosene de Aviação   m3  2022-09-10  2010  23.154
# 132  01  PE  Querosene de Aviação   m3  2022-09-10  2011  23.961
# 133  02  PE  Querosene de Aviação   m3  2022-09-10  2011  20.362
# 134  03  PE  Querosene de Aviação   m3  2022-09-10  2011  23.130
# 135  04  PE  Querosene de Aviação   m3  2022-09-10  2011  20.635
# 136  05  PE  Querosene de Aviação   m3  2022-09-10  2011  22.378
# 137  06  PE  Querosene de Aviação   m3  2022-09-10  2011  21.149
# 138  07  PE  Querosene de Aviação   m3  2022-09-10  2011  23.305
# 139  08  PE  Querosene de Aviação   m3  2022-09-10  2011  20.500
# 140  09  PE  Querosene de Aviação   m3  2022-09-10  2011  21.678
# 141  10  PE  Querosene de Aviação   m3  2022-09-10  2011  22.251
# 142  11  PE  Querosene de Aviação   m3  2022-09-10  2011  20.530
# 143  12  PE  Querosene de Aviação   m3  2022-09-10  2011  22.084
# 144  01  PE  Querosene de Aviação   m3  2022-09-10  2012  23.594
# 145  02  PE  Querosene de Aviação   m3  2022-09-10  2012  21.030
# 146  03  PE  Querosene de Aviação   m3  2022-09-10  2012  20.114
# 147  04  PE  Querosene de Aviação   m3  2022-09-10  2012  20.844
# 148  05  PE  Querosene de Aviação   m3  2022-09-10  2012  20.142
# 149  06  PE  Querosene de Aviação   m3  2022-09-10  2012  19.904
# 150  07  PE  Querosene de Aviação   m3  2022-09-10  2012  21.588
# 151  08  PE  Querosene de Aviação   m3  2022-09-10  2012  20.192
# 152  09  PE  Querosene de Aviação   m3  2022-09-10  2012  20.201
# 153  10  PE  Querosene de Aviação   m3  2022-09-10  2012  21.258
# 154  11  PE  Querosene de Aviação   m3  2022-09-10  2012  20.908
# 155  12  PE  Querosene de Aviação   m3  2022-09-10  2012  20.744
# 156  01  PE  Querosene de Aviação   m3  2022-09-10  2013  22.435
# 157  02  PE  Querosene de Aviação   m3  2022-09-10  2013  19.123
# 158  03  PE  Querosene de Aviação   m3  2022-09-10  2013  20.705
# 159  04  PE  Querosene de Aviação   m3  2022-09-10  2013  19.267
# 160  05  PE  Querosene de Aviação   m3  2022-09-10  2013  20.870
# 161  06  PE  Querosene de Aviação   m3  2022-09-10  2013  20.427
# 162  07  PE  Querosene de Aviação   m3  2022-09-10  2013  22.041
# 163  08  PE  Querosene de Aviação   m3  2022-09-10  2013  20.019
# 164  09  PE  Querosene de Aviação   m3  2022-09-10  2013  17.456
# 165  10  PE  Querosene de Aviação   m3  2022-09-10  2013  19.059
# 166  11  PE  Querosene de Aviação   m3  2022-09-10  2013  19.446
# 167  12  PE  Querosene de Aviação   m3  2022-09-10  2013  20.027
# 168  01  PE  Querosene de Aviação   m3  2022-09-10  2014  20.980
# 169  02  PE  Querosene de Aviação   m3  2022-09-10  2014  16.426
# 170  03  PE  Querosene de Aviação   m3  2022-09-10  2014  17.616
# 171  04  PE  Querosene de Aviação   m3  2022-09-10  2014  15.836
# 172  05  PE  Querosene de Aviação   m3  2022-09-10  2014  17.142
# 173  06  PE  Querosene de Aviação   m3  2022-09-10  2014  20.775
# 174  07  PE  Querosene de Aviação   m3  2022-09-10  2014  19.492
# 175  08  PE  Querosene de Aviação   m3  2022-09-10  2014  17.482
# 176  09  PE  Querosene de Aviação   m3  2022-09-10  2014  16.045
# 177  10  PE  Querosene de Aviação   m3  2022-09-10  2014  16.948
# 178  11  PE  Querosene de Aviação   m3  2022-09-10  2014  18.159
# 179  12  PE  Querosene de Aviação   m3  2022-09-10  2014  20.702
# 180  01  PE  Querosene de Aviação   m3  2022-09-10  2015  22.246
# 181  02  PE  Querosene de Aviação   m3  2022-09-10  2015  19.096
# 182  03  PE  Querosene de Aviação   m3  2022-09-10  2015  19.032
# 183  04  PE  Querosene de Aviação   m3  2022-09-10  2015  17.160
# 184  05  PE  Querosene de Aviação   m3  2022-09-10  2015  16.473
# 185  06  PE  Querosene de Aviação   m3  2022-09-10  2015  19.471
# 186  07  PE  Querosene de Aviação   m3  2022-09-10  2015  22.051
# 187  08  PE  Querosene de Aviação   m3  2022-09-10  2015  19.130
# 188  09  PE  Querosene de Aviação   m3  2022-09-10  2015  18.133
# 189  10  PE  Querosene de Aviação   m3  2022-09-10  2015  17.934
# 190  11  PE  Querosene de Aviação   m3  2022-09-10  2015  17.410
# 191  12  PE  Querosene de Aviação   m3  2022-09-10  2015  20.228
# 192  01  PE  Querosene de Aviação   m3  2022-09-10  2016  23.576
# 193  02  PE  Querosene de Aviação   m3  2022-09-10  2016  18.679
# 194  03  PE  Querosene de Aviação   m3  2022-09-10  2016  18.668
# 195  04  PE  Querosene de Aviação   m3  2022-09-10  2016  16.957
# 196  05  PE  Querosene de Aviação   m3  2022-09-10  2016  16.687
# 197  06  PE  Querosene de Aviação   m3  2022-09-10  2016  17.174
# 198  07  PE  Querosene de Aviação   m3  2022-09-10  2016  19.478
# 199  08  PE  Querosene de Aviação   m3  2022-09-10  2016  19.380
# 200  09  PE  Querosene de Aviação   m3  2022-09-10  2016  16.891
# 201  10  PE  Querosene de Aviação   m3  2022-09-10  2016  17.854
# 202  11  PE  Querosene de Aviação   m3  2022-09-10  2016  16.001
# 203  12  PE  Querosene de Aviação   m3  2022-09-10  2016  20.409
# 204  01  PE  Querosene de Aviação   m3  2022-09-10  2017  22.090
# 205  02  PE  Querosene de Aviação   m3  2022-09-10  2017  17.047
# 206  03  PE  Querosene de Aviação   m3  2022-09-10  2017  24.526
# 207  04  PE  Querosene de Aviação   m3  2022-09-10  2017  18.926
# 208  05  PE  Querosene de Aviação   m3  2022-09-10  2017  19.419
# 209  06  PE  Querosene de Aviação   m3  2022-09-10  2017  18.614
# 210  07  PE  Querosene de Aviação   m3  2022-09-10  2017  24.184
# 211  08  PE  Querosene de Aviação   m3  2022-09-10  2017  23.502
# 212  09  PE  Querosene de Aviação   m3  2022-09-10  2017  22.465
# 213  10  PE  Querosene de Aviação   m3  2022-09-10  2017  24.459
# 214  11  PE  Querosene de Aviação   m3  2022-09-10  2017  24.705
# 215  12  PE  Querosene de Aviação   m3  2022-09-10  2017  28.218
# 216  01  PE  Querosene de Aviação   m3  2022-09-10  2018  28.992
# 217  02  PE  Querosene de Aviação   m3  2022-09-10  2018  23.032
# 218  03  PE  Querosene de Aviação   m3  2022-09-10  2018  24.915
# 219  04  PE  Querosene de Aviação   m3  2022-09-10  2018  23.441
# 220  05  PE  Querosene de Aviação   m3  2022-09-10  2018  21.221
# 221  06  PE  Querosene de Aviação   m3  2022-09-10  2018  25.363
# 222  07  PE  Querosene de Aviação   m3  2022-09-10  2018  29.603
# 223  08  PE  Querosene de Aviação   m3  2022-09-10  2018  26.215
# 224  09  PE  Querosene de Aviação   m3  2022-09-10  2018  24.508
# 225  10  PE  Querosene de Aviação   m3  2022-09-10  2018  25.336
# 226  11  PE  Querosene de Aviação   m3  2022-09-10  2018  24.569
# 227  12  PE  Querosene de Aviação   m3  2022-09-10  2018  27.417
# 228  01  PE  Querosene de Aviação   m3  2022-09-10  2019  29.056
# 229  02  PE  Querosene de Aviação   m3  2022-09-10  2019  24.129
# 230  03  PE  Querosene de Aviação   m3  2022-09-10  2019  26.195
# 231  04  PE  Querosene de Aviação   m3  2022-09-10  2019  24.696
# 232  05  PE  Querosene de Aviação   m3  2022-09-10  2019  24.969
# 233  06  PE  Querosene de Aviação   m3  2022-09-10  2019  24.843
# 234  07  PE  Querosene de Aviação   m3  2022-09-10  2019  29.522
# 235  08  PE  Querosene de Aviação   m3  2022-09-10  2019  26.181
# 236  09  PE  Querosene de Aviação   m3  2022-09-10  2019  26.214
# 237  10  PE  Querosene de Aviação   m3  2022-09-10  2019  26.623
# 238  11  PE  Querosene de Aviação   m3  2022-09-10  2019  25.291
# 239  12  PE  Querosene de Aviação   m3  2022-09-10  2019  28.934
# 240  01  PE  Querosene de Aviação   m3  2022-09-10  2020  31.155
# 241  02  PE  Querosene de Aviação   m3  2022-09-10  2020  27.099
# 242  03  PE  Querosene de Aviação   m3  2022-09-10  2020  19.443
# 243  04  PE  Querosene de Aviação   m3  2022-09-10  2020   3.631
# 244  05  PE  Querosene de Aviação   m3  2022-09-10  2020   4.784
# 245  06  PE  Querosene de Aviação   m3  2022-09-10  2020   6.662
# 246  07  PE  Querosene de Aviação   m3  2022-09-10  2020   8.372
# 247  08  PE  Querosene de Aviação   m3  2022-09-10  2020  10.325
# 248  09  PE  Querosene de Aviação   m3  2022-09-10  2020  12.225
# 249  10  PE  Querosene de Aviação   m3  2022-09-10  2020  16.073
# 250  11  PE  Querosene de Aviação   m3  2022-09-10  2020  18.292
# 251  12  PE  Querosene de Aviação   m3  2022-09-10  2020  22.994
# 252  01  PE  Querosene de Aviação   m3  2022-09-10  2021  25.806
# 253  02  PE  Querosene de Aviação   m3  2022-09-10  2021  20.211
# 254  03  PE  Querosene de Aviação   m3  2022-09-10  2021  19.768
# 255  04  PE  Querosene de Aviação   m3  2022-09-10  2021  15.181
# 256  05  PE  Querosene de Aviação   m3  2022-09-10  2021  17.224
# 257  06  PE  Querosene de Aviação   m3  2022-09-10  2021  19.833
# 258  07  PE  Querosene de Aviação   m3  2022-09-10  2021  23.929
# 259  08  PE  Querosene de Aviação   m3  2022-09-10  2021  22.264
# 260  09  PE  Querosene de Aviação   m3  2022-09-10  2021  22.403
# 261  10  PE  Querosene de Aviação   m3  2022-09-10  2021  24.404
# 262  11  PE  Querosene de Aviação   m3  2022-09-10  2021  24.646
# 263  12  PE  Querosene de Aviação   m3  2022-09-10  2021  28.846
# 264  01  PE  Querosene de Aviação   m3  2022-09-10  2022  22.834
# 265  02  PE  Querosene de Aviação   m3  2022-09-10  2022  17.004
# 266  03  PE  Querosene de Aviação   m3  2022-09-10  2022  20.109
# 267  04  PE  Querosene de Aviação   m3  2022-09-10  2022  19.950
# 268  05  PE  Querosene de Aviação   m3  2022-09-10  2022  20.564
# 269  06  PE  Querosene de Aviação   m3  2022-09-10  2022  18.466
# 270  07  PE  Querosene de Aviação   m3  2022-09-10  2022     NaN
# 271  08  PE  Querosene de Aviação   m3  2022-09-10  2022     NaN
# 272  09  PE  Querosene de Aviação   m3  2022-09-10  2022     NaN
# 273  10  PE  Querosene de Aviação   m3  2022-09-10  2022     NaN
# 274  11  PE  Querosene de Aviação   m3  2022-09-10  2022     NaN
# 275  12  PE  Querosene de Aviação   m3  2022-09-10  2022     NaN

# %%
# Concatenando as colunas ano e Mês

dfpe['ano_mês'] = dfpe[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfpe.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfpe=dfpe[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfpe.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfpe.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfpe
# Out:
#      ano_mês  uf               produto unid  volume   criado_em
# 0    2000-01  PE  Querosene de Aviação   m3  18.509  2022-09-10
# 1    2000-02  PE  Querosene de Aviação   m3  16.942  2022-09-10
# 2    2000-03  PE  Querosene de Aviação   m3  17.425  2022-09-10
# 3    2000-04  PE  Querosene de Aviação   m3  16.144  2022-09-10
# 4    2000-05  PE  Querosene de Aviação   m3  15.371  2022-09-10
# 5    2000-06  PE  Querosene de Aviação   m3  14.391  2022-09-10
# 6    2000-07  PE  Querosene de Aviação   m3  15.714  2022-09-10
# 7    2000-08  PE  Querosene de Aviação   m3  14.965  2022-09-10
# 8    2000-09  PE  Querosene de Aviação   m3  15.483  2022-09-10
# 9    2000-10  PE  Querosene de Aviação   m3  15.396  2022-09-10
# 10   2000-11  PE  Querosene de Aviação   m3  16.184  2022-09-10
# 11   2000-12  PE  Querosene de Aviação   m3  18.121  2022-09-10
# 12   2001-01  PE  Querosene de Aviação   m3  18.963  2022-09-10
# 13   2001-02  PE  Querosene de Aviação   m3  15.943  2022-09-10
# 14   2001-03  PE  Querosene de Aviação   m3  16.246  2022-09-10
# 15   2001-04  PE  Querosene de Aviação   m3  14.915  2022-09-10
# 16   2001-05  PE  Querosene de Aviação   m3  15.359  2022-09-10
# 17   2001-06  PE  Querosene de Aviação   m3  14.439  2022-09-10
# 18   2001-07  PE  Querosene de Aviação   m3  16.359  2022-09-10
# 19   2001-08  PE  Querosene de Aviação   m3  15.695  2022-09-10
# 20   2001-09  PE  Querosene de Aviação   m3  14.566  2022-09-10
# 21   2001-10  PE  Querosene de Aviação   m3  15.599  2022-09-10
# 22   2001-11  PE  Querosene de Aviação   m3  14.956  2022-09-10
# 23   2001-12  PE  Querosene de Aviação   m3  15.713  2022-09-10
# 24   2002-01  PE  Querosene de Aviação   m3  15.899  2022-09-10
# 25   2002-02  PE  Querosene de Aviação   m3  14.785  2022-09-10
# 26   2002-03  PE  Querosene de Aviação   m3  15.513  2022-09-10
# 27   2002-04  PE  Querosene de Aviação   m3  15.377  2022-09-10
# 28   2002-05  PE  Querosene de Aviação   m3  15.396  2022-09-10
# 29   2002-06  PE  Querosene de Aviação   m3  14.593  2022-09-10
# 30   2002-07  PE  Querosene de Aviação   m3  15.840  2022-09-10
# 31   2002-08  PE  Querosene de Aviação   m3  37.601  2022-09-10
# 32   2002-09  PE  Querosene de Aviação   m3  14.665  2022-09-10
# 33   2002-10  PE  Querosene de Aviação   m3  14.786  2022-09-10
# 34   2002-11  PE  Querosene de Aviação   m3  13.047  2022-09-10
# 35   2002-12  PE  Querosene de Aviação   m3  14.636  2022-09-10
# 36   2003-01  PE  Querosene de Aviação   m3  15.976  2022-09-10
# 37   2003-02  PE  Querosene de Aviação   m3  13.158  2022-09-10
# 38   2003-03  PE  Querosene de Aviação   m3  13.352  2022-09-10
# 39   2003-04  PE  Querosene de Aviação   m3  13.348  2022-09-10
# 40   2003-05  PE  Querosene de Aviação   m3  11.316  2022-09-10
# 41   2003-06  PE  Querosene de Aviação   m3  11.068  2022-09-10
# 42   2003-07  PE  Querosene de Aviação   m3  13.199  2022-09-10
# 43   2003-08  PE  Querosene de Aviação   m3  12.413  2022-09-10
# 44   2003-09  PE  Querosene de Aviação   m3  12.068  2022-09-10
# 45   2003-10  PE  Querosene de Aviação   m3  12.534  2022-09-10
# 46   2003-11  PE  Querosene de Aviação   m3  13.566  2022-09-10
# 47   2003-12  PE  Querosene de Aviação   m3  13.899  2022-09-10
# 48   2004-01  PE  Querosene de Aviação   m3  14.635  2022-09-10
# 49   2004-02  PE  Querosene de Aviação   m3  12.474  2022-09-10
# 50   2004-03  PE  Querosene de Aviação   m3  13.481  2022-09-10
# 51   2004-04  PE  Querosene de Aviação   m3  13.543  2022-09-10
# 52   2004-05  PE  Querosene de Aviação   m3  13.823  2022-09-10
# 53   2004-06  PE  Querosene de Aviação   m3  13.133  2022-09-10
# 54   2004-07  PE  Querosene de Aviação   m3  14.212  2022-09-10
# 55   2004-08  PE  Querosene de Aviação   m3  13.556  2022-09-10
# 56   2004-09  PE  Querosene de Aviação   m3  12.913  2022-09-10
# 57   2004-10  PE  Querosene de Aviação   m3  12.755  2022-09-10
# 58   2004-11  PE  Querosene de Aviação   m3  13.032  2022-09-10
# 59   2004-12  PE  Querosene de Aviação   m3  13.674  2022-09-10
# 60   2005-01  PE  Querosene de Aviação   m3  14.833  2022-09-10
# 61   2005-02  PE  Querosene de Aviação   m3  12.272  2022-09-10
# 62   2005-03  PE  Querosene de Aviação   m3  14.207  2022-09-10
# 63   2005-04  PE  Querosene de Aviação   m3  12.802  2022-09-10
# 64   2005-05  PE  Querosene de Aviação   m3  14.050  2022-09-10
# 65   2005-06  PE  Querosene de Aviação   m3  13.119  2022-09-10
# 66   2005-07  PE  Querosene de Aviação   m3  15.259  2022-09-10
# 67   2005-08  PE  Querosene de Aviação   m3  15.180  2022-09-10
# 68   2005-09  PE  Querosene de Aviação   m3  13.759  2022-09-10
# 69   2005-10  PE  Querosene de Aviação   m3  14.916  2022-09-10
# 70   2005-11  PE  Querosene de Aviação   m3  14.415  2022-09-10
# 71   2005-12  PE  Querosene de Aviação   m3  17.526  2022-09-10
# 72   2006-01  PE  Querosene de Aviação   m3  17.976  2022-09-10
# 73   2006-02  PE  Querosene de Aviação   m3  15.513  2022-09-10
# 74   2006-03  PE  Querosene de Aviação   m3  17.487  2022-09-10
# 75   2006-04  PE  Querosene de Aviação   m3  14.620  2022-09-10
# 76   2006-05  PE  Querosene de Aviação   m3  16.391  2022-09-10
# 77   2006-06  PE  Querosene de Aviação   m3  14.099  2022-09-10
# 78   2006-07  PE  Querosene de Aviação   m3  15.378  2022-09-10
# 79   2006-08  PE  Querosene de Aviação   m3  13.304  2022-09-10
# 80   2006-09  PE  Querosene de Aviação   m3  12.992  2022-09-10
# 81   2006-10  PE  Querosene de Aviação   m3  13.608  2022-09-10
# 82   2006-11  PE  Querosene de Aviação   m3  13.978  2022-09-10
# 83   2006-12  PE  Querosene de Aviação   m3  15.811  2022-09-10
# 84   2007-01  PE  Querosene de Aviação   m3  16.579  2022-09-10
# 85   2007-02  PE  Querosene de Aviação   m3  14.224  2022-09-10
# 86   2007-03  PE  Querosene de Aviação   m3  16.157  2022-09-10
# 87   2007-04  PE  Querosene de Aviação   m3  15.747  2022-09-10
# 88   2007-05  PE  Querosene de Aviação   m3  14.834  2022-09-10
# 89   2007-06  PE  Querosene de Aviação   m3  14.454  2022-09-10
# 90   2007-07  PE  Querosene de Aviação   m3  17.533  2022-09-10
# 91   2007-08  PE  Querosene de Aviação   m3  16.391  2022-09-10
# 92   2007-09  PE  Querosene de Aviação   m3  14.986  2022-09-10
# 93   2007-10  PE  Querosene de Aviação   m3  16.586  2022-09-10
# 94   2007-11  PE  Querosene de Aviação   m3  15.840  2022-09-10
# 95   2007-12  PE  Querosene de Aviação   m3  16.847  2022-09-10
# 96   2008-01  PE  Querosene de Aviação   m3  17.711  2022-09-10
# 97   2008-02  PE  Querosene de Aviação   m3  15.757  2022-09-10
# 98   2008-03  PE  Querosene de Aviação   m3  16.878  2022-09-10
# 99   2008-04  PE  Querosene de Aviação   m3  15.490  2022-09-10
# 100  2008-05  PE  Querosene de Aviação   m3  16.392  2022-09-10
# 101  2008-06  PE  Querosene de Aviação   m3  16.004  2022-09-10
# 102  2008-07  PE  Querosene de Aviação   m3  17.594  2022-09-10
# 103  2008-08  PE  Querosene de Aviação   m3  16.105  2022-09-10
# 104  2008-09  PE  Querosene de Aviação   m3  15.922  2022-09-10
# 105  2008-10  PE  Querosene de Aviação   m3  16.176  2022-09-10
# 106  2008-11  PE  Querosene de Aviação   m3  18.388  2022-09-10
# 107  2008-12  PE  Querosene de Aviação   m3  18.565  2022-09-10
# 108  2009-01  PE  Querosene de Aviação   m3  19.891  2022-09-10
# 109  2009-02  PE  Querosene de Aviação   m3  15.727  2022-09-10
# 110  2009-03  PE  Querosene de Aviação   m3  17.139  2022-09-10
# 111  2009-04  PE  Querosene de Aviação   m3  16.066  2022-09-10
# 112  2009-05  PE  Querosene de Aviação   m3  15.759  2022-09-10
# 113  2009-06  PE  Querosene de Aviação   m3  16.524  2022-09-10
# 114  2009-07  PE  Querosene de Aviação   m3  19.184  2022-09-10
# 115  2009-08  PE  Querosene de Aviação   m3  18.421  2022-09-10
# 116  2009-09  PE  Querosene de Aviação   m3  17.569  2022-09-10
# 117  2009-10  PE  Querosene de Aviação   m3  18.672  2022-09-10
# 118  2009-11  PE  Querosene de Aviação   m3  18.568  2022-09-10
# 119  2009-12  PE  Querosene de Aviação   m3  20.171  2022-09-10
# 120  2010-01  PE  Querosene de Aviação   m3  20.682  2022-09-10
# 121  2010-02  PE  Querosene de Aviação   m3  18.229  2022-09-10
# 122  2010-03  PE  Querosene de Aviação   m3  19.891  2022-09-10
# 123  2010-04  PE  Querosene de Aviação   m3  18.739  2022-09-10
# 124  2010-05  PE  Querosene de Aviação   m3  18.673  2022-09-10
# 125  2010-06  PE  Querosene de Aviação   m3  18.311  2022-09-10
# 126  2010-07  PE  Querosene de Aviação   m3  20.922  2022-09-10
# 127  2010-08  PE  Querosene de Aviação   m3  20.447  2022-09-10
# 128  2010-09  PE  Querosene de Aviação   m3  20.325  2022-09-10
# 129  2010-10  PE  Querosene de Aviação   m3  21.556  2022-09-10
# 130  2010-11  PE  Querosene de Aviação   m3  22.817  2022-09-10
# 131  2010-12  PE  Querosene de Aviação   m3  23.154  2022-09-10
# 132  2011-01  PE  Querosene de Aviação   m3  23.961  2022-09-10
# 133  2011-02  PE  Querosene de Aviação   m3  20.362  2022-09-10
# 134  2011-03  PE  Querosene de Aviação   m3  23.130  2022-09-10
# 135  2011-04  PE  Querosene de Aviação   m3  20.635  2022-09-10
# 136  2011-05  PE  Querosene de Aviação   m3  22.378  2022-09-10
# 137  2011-06  PE  Querosene de Aviação   m3  21.149  2022-09-10
# 138  2011-07  PE  Querosene de Aviação   m3  23.305  2022-09-10
# 139  2011-08  PE  Querosene de Aviação   m3  20.500  2022-09-10
# 140  2011-09  PE  Querosene de Aviação   m3  21.678  2022-09-10
# 141  2011-10  PE  Querosene de Aviação   m3  22.251  2022-09-10
# 142  2011-11  PE  Querosene de Aviação   m3  20.530  2022-09-10
# 143  2011-12  PE  Querosene de Aviação   m3  22.084  2022-09-10
# 144  2012-01  PE  Querosene de Aviação   m3  23.594  2022-09-10
# 145  2012-02  PE  Querosene de Aviação   m3  21.030  2022-09-10
# 146  2012-03  PE  Querosene de Aviação   m3  20.114  2022-09-10
# 147  2012-04  PE  Querosene de Aviação   m3  20.844  2022-09-10
# 148  2012-05  PE  Querosene de Aviação   m3  20.142  2022-09-10
# 149  2012-06  PE  Querosene de Aviação   m3  19.904  2022-09-10
# 150  2012-07  PE  Querosene de Aviação   m3  21.588  2022-09-10
# 151  2012-08  PE  Querosene de Aviação   m3  20.192  2022-09-10
# 152  2012-09  PE  Querosene de Aviação   m3  20.201  2022-09-10
# 153  2012-10  PE  Querosene de Aviação   m3  21.258  2022-09-10
# 154  2012-11  PE  Querosene de Aviação   m3  20.908  2022-09-10
# 155  2012-12  PE  Querosene de Aviação   m3  20.744  2022-09-10
# 156  2013-01  PE  Querosene de Aviação   m3  22.435  2022-09-10
# 157  2013-02  PE  Querosene de Aviação   m3  19.123  2022-09-10
# 158  2013-03  PE  Querosene de Aviação   m3  20.705  2022-09-10
# 159  2013-04  PE  Querosene de Aviação   m3  19.267  2022-09-10
# 160  2013-05  PE  Querosene de Aviação   m3  20.870  2022-09-10
# 161  2013-06  PE  Querosene de Aviação   m3  20.427  2022-09-10
# 162  2013-07  PE  Querosene de Aviação   m3  22.041  2022-09-10
# 163  2013-08  PE  Querosene de Aviação   m3  20.019  2022-09-10
# 164  2013-09  PE  Querosene de Aviação   m3  17.456  2022-09-10
# 165  2013-10  PE  Querosene de Aviação   m3  19.059  2022-09-10
# 166  2013-11  PE  Querosene de Aviação   m3  19.446  2022-09-10
# 167  2013-12  PE  Querosene de Aviação   m3  20.027  2022-09-10
# 168  2014-01  PE  Querosene de Aviação   m3  20.980  2022-09-10
# 169  2014-02  PE  Querosene de Aviação   m3  16.426  2022-09-10
# 170  2014-03  PE  Querosene de Aviação   m3  17.616  2022-09-10
# 171  2014-04  PE  Querosene de Aviação   m3  15.836  2022-09-10
# 172  2014-05  PE  Querosene de Aviação   m3  17.142  2022-09-10
# 173  2014-06  PE  Querosene de Aviação   m3  20.775  2022-09-10
# 174  2014-07  PE  Querosene de Aviação   m3  19.492  2022-09-10
# 175  2014-08  PE  Querosene de Aviação   m3  17.482  2022-09-10
# 176  2014-09  PE  Querosene de Aviação   m3  16.045  2022-09-10
# 177  2014-10  PE  Querosene de Aviação   m3  16.948  2022-09-10
# 178  2014-11  PE  Querosene de Aviação   m3  18.159  2022-09-10
# 179  2014-12  PE  Querosene de Aviação   m3  20.702  2022-09-10
# 180  2015-01  PE  Querosene de Aviação   m3  22.246  2022-09-10
# 181  2015-02  PE  Querosene de Aviação   m3  19.096  2022-09-10
# 182  2015-03  PE  Querosene de Aviação   m3  19.032  2022-09-10
# 183  2015-04  PE  Querosene de Aviação   m3  17.160  2022-09-10
# 184  2015-05  PE  Querosene de Aviação   m3  16.473  2022-09-10
# 185  2015-06  PE  Querosene de Aviação   m3  19.471  2022-09-10
# 186  2015-07  PE  Querosene de Aviação   m3  22.051  2022-09-10
# 187  2015-08  PE  Querosene de Aviação   m3  19.130  2022-09-10
# 188  2015-09  PE  Querosene de Aviação   m3  18.133  2022-09-10
# 189  2015-10  PE  Querosene de Aviação   m3  17.934  2022-09-10
# 190  2015-11  PE  Querosene de Aviação   m3  17.410  2022-09-10
# 191  2015-12  PE  Querosene de Aviação   m3  20.228  2022-09-10
# 192  2016-01  PE  Querosene de Aviação   m3  23.576  2022-09-10
# 193  2016-02  PE  Querosene de Aviação   m3  18.679  2022-09-10
# 194  2016-03  PE  Querosene de Aviação   m3  18.668  2022-09-10
# 195  2016-04  PE  Querosene de Aviação   m3  16.957  2022-09-10
# 196  2016-05  PE  Querosene de Aviação   m3  16.687  2022-09-10
# 197  2016-06  PE  Querosene de Aviação   m3  17.174  2022-09-10
# 198  2016-07  PE  Querosene de Aviação   m3  19.478  2022-09-10
# 199  2016-08  PE  Querosene de Aviação   m3  19.380  2022-09-10
# 200  2016-09  PE  Querosene de Aviação   m3  16.891  2022-09-10
# 201  2016-10  PE  Querosene de Aviação   m3  17.854  2022-09-10
# 202  2016-11  PE  Querosene de Aviação   m3  16.001  2022-09-10
# 203  2016-12  PE  Querosene de Aviação   m3  20.409  2022-09-10
# 204  2017-01  PE  Querosene de Aviação   m3  22.090  2022-09-10
# 205  2017-02  PE  Querosene de Aviação   m3  17.047  2022-09-10
# 206  2017-03  PE  Querosene de Aviação   m3  24.526  2022-09-10
# 207  2017-04  PE  Querosene de Aviação   m3  18.926  2022-09-10
# 208  2017-05  PE  Querosene de Aviação   m3  19.419  2022-09-10
# 209  2017-06  PE  Querosene de Aviação   m3  18.614  2022-09-10
# 210  2017-07  PE  Querosene de Aviação   m3  24.184  2022-09-10
# 211  2017-08  PE  Querosene de Aviação   m3  23.502  2022-09-10
# 212  2017-09  PE  Querosene de Aviação   m3  22.465  2022-09-10
# 213  2017-10  PE  Querosene de Aviação   m3  24.459  2022-09-10
# 214  2017-11  PE  Querosene de Aviação   m3  24.705  2022-09-10
# 215  2017-12  PE  Querosene de Aviação   m3  28.218  2022-09-10
# 216  2018-01  PE  Querosene de Aviação   m3  28.992  2022-09-10
# 217  2018-02  PE  Querosene de Aviação   m3  23.032  2022-09-10
# 218  2018-03  PE  Querosene de Aviação   m3  24.915  2022-09-10
# 219  2018-04  PE  Querosene de Aviação   m3  23.441  2022-09-10
# 220  2018-05  PE  Querosene de Aviação   m3  21.221  2022-09-10
# 221  2018-06  PE  Querosene de Aviação   m3  25.363  2022-09-10
# 222  2018-07  PE  Querosene de Aviação   m3  29.603  2022-09-10
# 223  2018-08  PE  Querosene de Aviação   m3  26.215  2022-09-10
# 224  2018-09  PE  Querosene de Aviação   m3  24.508  2022-09-10
# 225  2018-10  PE  Querosene de Aviação   m3  25.336  2022-09-10
# 226  2018-11  PE  Querosene de Aviação   m3  24.569  2022-09-10
# 227  2018-12  PE  Querosene de Aviação   m3  27.417  2022-09-10
# 228  2019-01  PE  Querosene de Aviação   m3  29.056  2022-09-10
# 229  2019-02  PE  Querosene de Aviação   m3  24.129  2022-09-10
# 230  2019-03  PE  Querosene de Aviação   m3  26.195  2022-09-10
# 231  2019-04  PE  Querosene de Aviação   m3  24.696  2022-09-10
# 232  2019-05  PE  Querosene de Aviação   m3  24.969  2022-09-10
# 233  2019-06  PE  Querosene de Aviação   m3  24.843  2022-09-10
# 234  2019-07  PE  Querosene de Aviação   m3  29.522  2022-09-10
# 235  2019-08  PE  Querosene de Aviação   m3  26.181  2022-09-10
# 236  2019-09  PE  Querosene de Aviação   m3  26.214  2022-09-10
# 237  2019-10  PE  Querosene de Aviação   m3  26.623  2022-09-10
# 238  2019-11  PE  Querosene de Aviação   m3  25.291  2022-09-10
# 239  2019-12  PE  Querosene de Aviação   m3  28.934  2022-09-10
# 240  2020-01  PE  Querosene de Aviação   m3  31.155  2022-09-10
# 241  2020-02  PE  Querosene de Aviação   m3  27.099  2022-09-10
# 242  2020-03  PE  Querosene de Aviação   m3  19.443  2022-09-10
# 243  2020-04  PE  Querosene de Aviação   m3   3.631  2022-09-10
# 244  2020-05  PE  Querosene de Aviação   m3   4.784  2022-09-10
# 245  2020-06  PE  Querosene de Aviação   m3   6.662  2022-09-10
# 246  2020-07  PE  Querosene de Aviação   m3   8.372  2022-09-10
# 247  2020-08  PE  Querosene de Aviação   m3  10.325  2022-09-10
# 248  2020-09  PE  Querosene de Aviação   m3  12.225  2022-09-10
# 249  2020-10  PE  Querosene de Aviação   m3  16.073  2022-09-10
# 250  2020-11  PE  Querosene de Aviação   m3  18.292  2022-09-10
# 251  2020-12  PE  Querosene de Aviação   m3  22.994  2022-09-10
# 252  2021-01  PE  Querosene de Aviação   m3  25.806  2022-09-10
# 253  2021-02  PE  Querosene de Aviação   m3  20.211  2022-09-10
# 254  2021-03  PE  Querosene de Aviação   m3  19.768  2022-09-10
# 255  2021-04  PE  Querosene de Aviação   m3  15.181  2022-09-10
# 256  2021-05  PE  Querosene de Aviação   m3  17.224  2022-09-10
# 257  2021-06  PE  Querosene de Aviação   m3  19.833  2022-09-10
# 258  2021-07  PE  Querosene de Aviação   m3  23.929  2022-09-10
# 259  2021-08  PE  Querosene de Aviação   m3  22.264  2022-09-10
# 260  2021-09  PE  Querosene de Aviação   m3  22.403  2022-09-10
# 261  2021-10  PE  Querosene de Aviação   m3  24.404  2022-09-10
# 262  2021-11  PE  Querosene de Aviação   m3  24.646  2022-09-10
# 263  2021-12  PE  Querosene de Aviação   m3  28.846  2022-09-10
# 264  2022-01  PE  Querosene de Aviação   m3  22.834  2022-09-10
# 265  2022-02  PE  Querosene de Aviação   m3  17.004  2022-09-10
# 266  2022-03  PE  Querosene de Aviação   m3  20.109  2022-09-10
# 267  2022-04  PE  Querosene de Aviação   m3  19.950  2022-09-10
# 268  2022-05  PE  Querosene de Aviação   m3  20.564  2022-09-10
# 269  2022-06  PE  Querosene de Aviação   m3  18.466  2022-09-10
# 270  2022-07  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 271  2022-08  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 272  2022-09  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 273  2022-10  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 274  2022-11  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 275  2022-12  PE  Querosene de Aviação   m3     NaN  2022-09-10

# %%
# Verificando os tipos

dfpe.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfpe)
# Out:
#      ano_mês  uf               produto unid  volume   criado_em
# 0    2000-01  PE  Querosene de Aviação   m3  18.509  2022-09-10
# 1    2000-02  PE  Querosene de Aviação   m3  16.942  2022-09-10
# 2    2000-03  PE  Querosene de Aviação   m3  17.425  2022-09-10
# 3    2000-04  PE  Querosene de Aviação   m3  16.144  2022-09-10
# 4    2000-05  PE  Querosene de Aviação   m3  15.371  2022-09-10
# 5    2000-06  PE  Querosene de Aviação   m3  14.391  2022-09-10
# 6    2000-07  PE  Querosene de Aviação   m3  15.714  2022-09-10
# 7    2000-08  PE  Querosene de Aviação   m3  14.965  2022-09-10
# 8    2000-09  PE  Querosene de Aviação   m3  15.483  2022-09-10
# 9    2000-10  PE  Querosene de Aviação   m3  15.396  2022-09-10
# 10   2000-11  PE  Querosene de Aviação   m3  16.184  2022-09-10
# 11   2000-12  PE  Querosene de Aviação   m3  18.121  2022-09-10
# 12   2001-01  PE  Querosene de Aviação   m3  18.963  2022-09-10
# 13   2001-02  PE  Querosene de Aviação   m3  15.943  2022-09-10
# 14   2001-03  PE  Querosene de Aviação   m3  16.246  2022-09-10
# 15   2001-04  PE  Querosene de Aviação   m3  14.915  2022-09-10
# 16   2001-05  PE  Querosene de Aviação   m3  15.359  2022-09-10
# 17   2001-06  PE  Querosene de Aviação   m3  14.439  2022-09-10
# 18   2001-07  PE  Querosene de Aviação   m3  16.359  2022-09-10
# 19   2001-08  PE  Querosene de Aviação   m3  15.695  2022-09-10
# 20   2001-09  PE  Querosene de Aviação   m3  14.566  2022-09-10
# 21   2001-10  PE  Querosene de Aviação   m3  15.599  2022-09-10
# 22   2001-11  PE  Querosene de Aviação   m3  14.956  2022-09-10
# 23   2001-12  PE  Querosene de Aviação   m3  15.713  2022-09-10
# 24   2002-01  PE  Querosene de Aviação   m3  15.899  2022-09-10
# 25   2002-02  PE  Querosene de Aviação   m3  14.785  2022-09-10
# 26   2002-03  PE  Querosene de Aviação   m3  15.513  2022-09-10
# 27   2002-04  PE  Querosene de Aviação   m3  15.377  2022-09-10
# 28   2002-05  PE  Querosene de Aviação   m3  15.396  2022-09-10
# 29   2002-06  PE  Querosene de Aviação   m3  14.593  2022-09-10
# 30   2002-07  PE  Querosene de Aviação   m3  15.840  2022-09-10
# 31   2002-08  PE  Querosene de Aviação   m3  37.601  2022-09-10
# 32   2002-09  PE  Querosene de Aviação   m3  14.665  2022-09-10
# 33   2002-10  PE  Querosene de Aviação   m3  14.786  2022-09-10
# 34   2002-11  PE  Querosene de Aviação   m3  13.047  2022-09-10
# 35   2002-12  PE  Querosene de Aviação   m3  14.636  2022-09-10
# 36   2003-01  PE  Querosene de Aviação   m3  15.976  2022-09-10
# 37   2003-02  PE  Querosene de Aviação   m3  13.158  2022-09-10
# 38   2003-03  PE  Querosene de Aviação   m3  13.352  2022-09-10
# 39   2003-04  PE  Querosene de Aviação   m3  13.348  2022-09-10
# 40   2003-05  PE  Querosene de Aviação   m3  11.316  2022-09-10
# 41   2003-06  PE  Querosene de Aviação   m3  11.068  2022-09-10
# 42   2003-07  PE  Querosene de Aviação   m3  13.199  2022-09-10
# 43   2003-08  PE  Querosene de Aviação   m3  12.413  2022-09-10
# 44   2003-09  PE  Querosene de Aviação   m3  12.068  2022-09-10
# 45   2003-10  PE  Querosene de Aviação   m3  12.534  2022-09-10
# 46   2003-11  PE  Querosene de Aviação   m3  13.566  2022-09-10
# 47   2003-12  PE  Querosene de Aviação   m3  13.899  2022-09-10
# 48   2004-01  PE  Querosene de Aviação   m3  14.635  2022-09-10
# 49   2004-02  PE  Querosene de Aviação   m3  12.474  2022-09-10
# 50   2004-03  PE  Querosene de Aviação   m3  13.481  2022-09-10
# 51   2004-04  PE  Querosene de Aviação   m3  13.543  2022-09-10
# 52   2004-05  PE  Querosene de Aviação   m3  13.823  2022-09-10
# 53   2004-06  PE  Querosene de Aviação   m3  13.133  2022-09-10
# 54   2004-07  PE  Querosene de Aviação   m3  14.212  2022-09-10
# 55   2004-08  PE  Querosene de Aviação   m3  13.556  2022-09-10
# 56   2004-09  PE  Querosene de Aviação   m3  12.913  2022-09-10
# 57   2004-10  PE  Querosene de Aviação   m3  12.755  2022-09-10
# 58   2004-11  PE  Querosene de Aviação   m3  13.032  2022-09-10
# 59   2004-12  PE  Querosene de Aviação   m3  13.674  2022-09-10
# 60   2005-01  PE  Querosene de Aviação   m3  14.833  2022-09-10
# 61   2005-02  PE  Querosene de Aviação   m3  12.272  2022-09-10
# 62   2005-03  PE  Querosene de Aviação   m3  14.207  2022-09-10
# 63   2005-04  PE  Querosene de Aviação   m3  12.802  2022-09-10
# 64   2005-05  PE  Querosene de Aviação   m3  14.050  2022-09-10
# 65   2005-06  PE  Querosene de Aviação   m3  13.119  2022-09-10
# 66   2005-07  PE  Querosene de Aviação   m3  15.259  2022-09-10
# 67   2005-08  PE  Querosene de Aviação   m3  15.180  2022-09-10
# 68   2005-09  PE  Querosene de Aviação   m3  13.759  2022-09-10
# 69   2005-10  PE  Querosene de Aviação   m3  14.916  2022-09-10
# 70   2005-11  PE  Querosene de Aviação   m3  14.415  2022-09-10
# 71   2005-12  PE  Querosene de Aviação   m3  17.526  2022-09-10
# 72   2006-01  PE  Querosene de Aviação   m3  17.976  2022-09-10
# 73   2006-02  PE  Querosene de Aviação   m3  15.513  2022-09-10
# 74   2006-03  PE  Querosene de Aviação   m3  17.487  2022-09-10
# 75   2006-04  PE  Querosene de Aviação   m3  14.620  2022-09-10
# 76   2006-05  PE  Querosene de Aviação   m3  16.391  2022-09-10
# 77   2006-06  PE  Querosene de Aviação   m3  14.099  2022-09-10
# 78   2006-07  PE  Querosene de Aviação   m3  15.378  2022-09-10
# 79   2006-08  PE  Querosene de Aviação   m3  13.304  2022-09-10
# 80   2006-09  PE  Querosene de Aviação   m3  12.992  2022-09-10
# 81   2006-10  PE  Querosene de Aviação   m3  13.608  2022-09-10
# 82   2006-11  PE  Querosene de Aviação   m3  13.978  2022-09-10
# 83   2006-12  PE  Querosene de Aviação   m3  15.811  2022-09-10
# 84   2007-01  PE  Querosene de Aviação   m3  16.579  2022-09-10
# 85   2007-02  PE  Querosene de Aviação   m3  14.224  2022-09-10
# 86   2007-03  PE  Querosene de Aviação   m3  16.157  2022-09-10
# 87   2007-04  PE  Querosene de Aviação   m3  15.747  2022-09-10
# 88   2007-05  PE  Querosene de Aviação   m3  14.834  2022-09-10
# 89   2007-06  PE  Querosene de Aviação   m3  14.454  2022-09-10
# 90   2007-07  PE  Querosene de Aviação   m3  17.533  2022-09-10
# 91   2007-08  PE  Querosene de Aviação   m3  16.391  2022-09-10
# 92   2007-09  PE  Querosene de Aviação   m3  14.986  2022-09-10
# 93   2007-10  PE  Querosene de Aviação   m3  16.586  2022-09-10
# 94   2007-11  PE  Querosene de Aviação   m3  15.840  2022-09-10
# 95   2007-12  PE  Querosene de Aviação   m3  16.847  2022-09-10
# 96   2008-01  PE  Querosene de Aviação   m3  17.711  2022-09-10
# 97   2008-02  PE  Querosene de Aviação   m3  15.757  2022-09-10
# 98   2008-03  PE  Querosene de Aviação   m3  16.878  2022-09-10
# 99   2008-04  PE  Querosene de Aviação   m3  15.490  2022-09-10
# 100  2008-05  PE  Querosene de Aviação   m3  16.392  2022-09-10
# 101  2008-06  PE  Querosene de Aviação   m3  16.004  2022-09-10
# 102  2008-07  PE  Querosene de Aviação   m3  17.594  2022-09-10
# 103  2008-08  PE  Querosene de Aviação   m3  16.105  2022-09-10
# 104  2008-09  PE  Querosene de Aviação   m3  15.922  2022-09-10
# 105  2008-10  PE  Querosene de Aviação   m3  16.176  2022-09-10
# 106  2008-11  PE  Querosene de Aviação   m3  18.388  2022-09-10
# 107  2008-12  PE  Querosene de Aviação   m3  18.565  2022-09-10
# 108  2009-01  PE  Querosene de Aviação   m3  19.891  2022-09-10
# 109  2009-02  PE  Querosene de Aviação   m3  15.727  2022-09-10
# 110  2009-03  PE  Querosene de Aviação   m3  17.139  2022-09-10
# 111  2009-04  PE  Querosene de Aviação   m3  16.066  2022-09-10
# 112  2009-05  PE  Querosene de Aviação   m3  15.759  2022-09-10
# 113  2009-06  PE  Querosene de Aviação   m3  16.524  2022-09-10
# 114  2009-07  PE  Querosene de Aviação   m3  19.184  2022-09-10
# 115  2009-08  PE  Querosene de Aviação   m3  18.421  2022-09-10
# 116  2009-09  PE  Querosene de Aviação   m3  17.569  2022-09-10
# 117  2009-10  PE  Querosene de Aviação   m3  18.672  2022-09-10
# 118  2009-11  PE  Querosene de Aviação   m3  18.568  2022-09-10
# 119  2009-12  PE  Querosene de Aviação   m3  20.171  2022-09-10
# 120  2010-01  PE  Querosene de Aviação   m3  20.682  2022-09-10
# 121  2010-02  PE  Querosene de Aviação   m3  18.229  2022-09-10
# 122  2010-03  PE  Querosene de Aviação   m3  19.891  2022-09-10
# 123  2010-04  PE  Querosene de Aviação   m3  18.739  2022-09-10
# 124  2010-05  PE  Querosene de Aviação   m3  18.673  2022-09-10
# 125  2010-06  PE  Querosene de Aviação   m3  18.311  2022-09-10
# 126  2010-07  PE  Querosene de Aviação   m3  20.922  2022-09-10
# 127  2010-08  PE  Querosene de Aviação   m3  20.447  2022-09-10
# 128  2010-09  PE  Querosene de Aviação   m3  20.325  2022-09-10
# 129  2010-10  PE  Querosene de Aviação   m3  21.556  2022-09-10
# 130  2010-11  PE  Querosene de Aviação   m3  22.817  2022-09-10
# 131  2010-12  PE  Querosene de Aviação   m3  23.154  2022-09-10
# 132  2011-01  PE  Querosene de Aviação   m3  23.961  2022-09-10
# 133  2011-02  PE  Querosene de Aviação   m3  20.362  2022-09-10
# 134  2011-03  PE  Querosene de Aviação   m3  23.130  2022-09-10
# 135  2011-04  PE  Querosene de Aviação   m3  20.635  2022-09-10
# 136  2011-05  PE  Querosene de Aviação   m3  22.378  2022-09-10
# 137  2011-06  PE  Querosene de Aviação   m3  21.149  2022-09-10
# 138  2011-07  PE  Querosene de Aviação   m3  23.305  2022-09-10
# 139  2011-08  PE  Querosene de Aviação   m3  20.500  2022-09-10
# 140  2011-09  PE  Querosene de Aviação   m3  21.678  2022-09-10
# 141  2011-10  PE  Querosene de Aviação   m3  22.251  2022-09-10
# 142  2011-11  PE  Querosene de Aviação   m3  20.530  2022-09-10
# 143  2011-12  PE  Querosene de Aviação   m3  22.084  2022-09-10
# 144  2012-01  PE  Querosene de Aviação   m3  23.594  2022-09-10
# 145  2012-02  PE  Querosene de Aviação   m3  21.030  2022-09-10
# 146  2012-03  PE  Querosene de Aviação   m3  20.114  2022-09-10
# 147  2012-04  PE  Querosene de Aviação   m3  20.844  2022-09-10
# 148  2012-05  PE  Querosene de Aviação   m3  20.142  2022-09-10
# 149  2012-06  PE  Querosene de Aviação   m3  19.904  2022-09-10
# 150  2012-07  PE  Querosene de Aviação   m3  21.588  2022-09-10
# 151  2012-08  PE  Querosene de Aviação   m3  20.192  2022-09-10
# 152  2012-09  PE  Querosene de Aviação   m3  20.201  2022-09-10
# 153  2012-10  PE  Querosene de Aviação   m3  21.258  2022-09-10
# 154  2012-11  PE  Querosene de Aviação   m3  20.908  2022-09-10
# 155  2012-12  PE  Querosene de Aviação   m3  20.744  2022-09-10
# 156  2013-01  PE  Querosene de Aviação   m3  22.435  2022-09-10
# 157  2013-02  PE  Querosene de Aviação   m3  19.123  2022-09-10
# 158  2013-03  PE  Querosene de Aviação   m3  20.705  2022-09-10
# 159  2013-04  PE  Querosene de Aviação   m3  19.267  2022-09-10
# 160  2013-05  PE  Querosene de Aviação   m3  20.870  2022-09-10
# 161  2013-06  PE  Querosene de Aviação   m3  20.427  2022-09-10
# 162  2013-07  PE  Querosene de Aviação   m3  22.041  2022-09-10
# 163  2013-08  PE  Querosene de Aviação   m3  20.019  2022-09-10
# 164  2013-09  PE  Querosene de Aviação   m3  17.456  2022-09-10
# 165  2013-10  PE  Querosene de Aviação   m3  19.059  2022-09-10
# 166  2013-11  PE  Querosene de Aviação   m3  19.446  2022-09-10
# 167  2013-12  PE  Querosene de Aviação   m3  20.027  2022-09-10
# 168  2014-01  PE  Querosene de Aviação   m3  20.980  2022-09-10
# 169  2014-02  PE  Querosene de Aviação   m3  16.426  2022-09-10
# 170  2014-03  PE  Querosene de Aviação   m3  17.616  2022-09-10
# 171  2014-04  PE  Querosene de Aviação   m3  15.836  2022-09-10
# 172  2014-05  PE  Querosene de Aviação   m3  17.142  2022-09-10
# 173  2014-06  PE  Querosene de Aviação   m3  20.775  2022-09-10
# 174  2014-07  PE  Querosene de Aviação   m3  19.492  2022-09-10
# 175  2014-08  PE  Querosene de Aviação   m3  17.482  2022-09-10
# 176  2014-09  PE  Querosene de Aviação   m3  16.045  2022-09-10
# 177  2014-10  PE  Querosene de Aviação   m3  16.948  2022-09-10
# 178  2014-11  PE  Querosene de Aviação   m3  18.159  2022-09-10
# 179  2014-12  PE  Querosene de Aviação   m3  20.702  2022-09-10
# 180  2015-01  PE  Querosene de Aviação   m3  22.246  2022-09-10
# 181  2015-02  PE  Querosene de Aviação   m3  19.096  2022-09-10
# 182  2015-03  PE  Querosene de Aviação   m3  19.032  2022-09-10
# 183  2015-04  PE  Querosene de Aviação   m3  17.160  2022-09-10
# 184  2015-05  PE  Querosene de Aviação   m3  16.473  2022-09-10
# 185  2015-06  PE  Querosene de Aviação   m3  19.471  2022-09-10
# 186  2015-07  PE  Querosene de Aviação   m3  22.051  2022-09-10
# 187  2015-08  PE  Querosene de Aviação   m3  19.130  2022-09-10
# 188  2015-09  PE  Querosene de Aviação   m3  18.133  2022-09-10
# 189  2015-10  PE  Querosene de Aviação   m3  17.934  2022-09-10
# 190  2015-11  PE  Querosene de Aviação   m3  17.410  2022-09-10
# 191  2015-12  PE  Querosene de Aviação   m3  20.228  2022-09-10
# 192  2016-01  PE  Querosene de Aviação   m3  23.576  2022-09-10
# 193  2016-02  PE  Querosene de Aviação   m3  18.679  2022-09-10
# 194  2016-03  PE  Querosene de Aviação   m3  18.668  2022-09-10
# 195  2016-04  PE  Querosene de Aviação   m3  16.957  2022-09-10
# 196  2016-05  PE  Querosene de Aviação   m3  16.687  2022-09-10
# 197  2016-06  PE  Querosene de Aviação   m3  17.174  2022-09-10
# 198  2016-07  PE  Querosene de Aviação   m3  19.478  2022-09-10
# 199  2016-08  PE  Querosene de Aviação   m3  19.380  2022-09-10
# 200  2016-09  PE  Querosene de Aviação   m3  16.891  2022-09-10
# 201  2016-10  PE  Querosene de Aviação   m3  17.854  2022-09-10
# 202  2016-11  PE  Querosene de Aviação   m3  16.001  2022-09-10
# 203  2016-12  PE  Querosene de Aviação   m3  20.409  2022-09-10
# 204  2017-01  PE  Querosene de Aviação   m3  22.090  2022-09-10
# 205  2017-02  PE  Querosene de Aviação   m3  17.047  2022-09-10
# 206  2017-03  PE  Querosene de Aviação   m3  24.526  2022-09-10
# 207  2017-04  PE  Querosene de Aviação   m3  18.926  2022-09-10
# 208  2017-05  PE  Querosene de Aviação   m3  19.419  2022-09-10
# 209  2017-06  PE  Querosene de Aviação   m3  18.614  2022-09-10
# 210  2017-07  PE  Querosene de Aviação   m3  24.184  2022-09-10
# 211  2017-08  PE  Querosene de Aviação   m3  23.502  2022-09-10
# 212  2017-09  PE  Querosene de Aviação   m3  22.465  2022-09-10
# 213  2017-10  PE  Querosene de Aviação   m3  24.459  2022-09-10
# 214  2017-11  PE  Querosene de Aviação   m3  24.705  2022-09-10
# 215  2017-12  PE  Querosene de Aviação   m3  28.218  2022-09-10
# 216  2018-01  PE  Querosene de Aviação   m3  28.992  2022-09-10
# 217  2018-02  PE  Querosene de Aviação   m3  23.032  2022-09-10
# 218  2018-03  PE  Querosene de Aviação   m3  24.915  2022-09-10
# 219  2018-04  PE  Querosene de Aviação   m3  23.441  2022-09-10
# 220  2018-05  PE  Querosene de Aviação   m3  21.221  2022-09-10
# 221  2018-06  PE  Querosene de Aviação   m3  25.363  2022-09-10
# 222  2018-07  PE  Querosene de Aviação   m3  29.603  2022-09-10
# 223  2018-08  PE  Querosene de Aviação   m3  26.215  2022-09-10
# 224  2018-09  PE  Querosene de Aviação   m3  24.508  2022-09-10
# 225  2018-10  PE  Querosene de Aviação   m3  25.336  2022-09-10
# 226  2018-11  PE  Querosene de Aviação   m3  24.569  2022-09-10
# 227  2018-12  PE  Querosene de Aviação   m3  27.417  2022-09-10
# 228  2019-01  PE  Querosene de Aviação   m3  29.056  2022-09-10
# 229  2019-02  PE  Querosene de Aviação   m3  24.129  2022-09-10
# 230  2019-03  PE  Querosene de Aviação   m3  26.195  2022-09-10
# 231  2019-04  PE  Querosene de Aviação   m3  24.696  2022-09-10
# 232  2019-05  PE  Querosene de Aviação   m3  24.969  2022-09-10
# 233  2019-06  PE  Querosene de Aviação   m3  24.843  2022-09-10
# 234  2019-07  PE  Querosene de Aviação   m3  29.522  2022-09-10
# 235  2019-08  PE  Querosene de Aviação   m3  26.181  2022-09-10
# 236  2019-09  PE  Querosene de Aviação   m3  26.214  2022-09-10
# 237  2019-10  PE  Querosene de Aviação   m3  26.623  2022-09-10
# 238  2019-11  PE  Querosene de Aviação   m3  25.291  2022-09-10
# 239  2019-12  PE  Querosene de Aviação   m3  28.934  2022-09-10
# 240  2020-01  PE  Querosene de Aviação   m3  31.155  2022-09-10
# 241  2020-02  PE  Querosene de Aviação   m3  27.099  2022-09-10
# 242  2020-03  PE  Querosene de Aviação   m3  19.443  2022-09-10
# 243  2020-04  PE  Querosene de Aviação   m3   3.631  2022-09-10
# 244  2020-05  PE  Querosene de Aviação   m3   4.784  2022-09-10
# 245  2020-06  PE  Querosene de Aviação   m3   6.662  2022-09-10
# 246  2020-07  PE  Querosene de Aviação   m3   8.372  2022-09-10
# 247  2020-08  PE  Querosene de Aviação   m3  10.325  2022-09-10
# 248  2020-09  PE  Querosene de Aviação   m3  12.225  2022-09-10
# 249  2020-10  PE  Querosene de Aviação   m3  16.073  2022-09-10
# 250  2020-11  PE  Querosene de Aviação   m3  18.292  2022-09-10
# 251  2020-12  PE  Querosene de Aviação   m3  22.994  2022-09-10
# 252  2021-01  PE  Querosene de Aviação   m3  25.806  2022-09-10
# 253  2021-02  PE  Querosene de Aviação   m3  20.211  2022-09-10
# 254  2021-03  PE  Querosene de Aviação   m3  19.768  2022-09-10
# 255  2021-04  PE  Querosene de Aviação   m3  15.181  2022-09-10
# 256  2021-05  PE  Querosene de Aviação   m3  17.224  2022-09-10
# 257  2021-06  PE  Querosene de Aviação   m3  19.833  2022-09-10
# 258  2021-07  PE  Querosene de Aviação   m3  23.929  2022-09-10
# 259  2021-08  PE  Querosene de Aviação   m3  22.264  2022-09-10
# 260  2021-09  PE  Querosene de Aviação   m3  22.403  2022-09-10
# 261  2021-10  PE  Querosene de Aviação   m3  24.404  2022-09-10
# 262  2021-11  PE  Querosene de Aviação   m3  24.646  2022-09-10
# 263  2021-12  PE  Querosene de Aviação   m3  28.846  2022-09-10
# 264  2022-01  PE  Querosene de Aviação   m3  22.834  2022-09-10
# 265  2022-02  PE  Querosene de Aviação   m3  17.004  2022-09-10
# 266  2022-03  PE  Querosene de Aviação   m3  20.109  2022-09-10
# 267  2022-04  PE  Querosene de Aviação   m3  19.950  2022-09-10
# 268  2022-05  PE  Querosene de Aviação   m3  20.564  2022-09-10
# 269  2022-06  PE  Querosene de Aviação   m3  18.466  2022-09-10
# 270  2022-07  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 271  2022-08  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 272  2022-09  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 273  2022-10  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 274  2022-11  PE  Querosene de Aviação   m3     NaN  2022-09-10
# 275  2022-12  PE  Querosene de Aviação   m3     NaN  2022-09-10

# %%
dfpe_pandas = dfpe.copy()

# %% [markdown]
# ##PIAUÍ

# %%
# Conector

dfpi = pd.read_csv('/content/PI_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfpi_backup = dfpi.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfpi

# %%
# Replace do Mês para numérico

dfpi["Mês"].replace("Janeiro", "01", inplace=True)
dfpi["Mês"].replace("Fevereiro", "02", inplace=True)
dfpi["Mês"].replace("Março", "03", inplace=True)
dfpi["Mês"].replace("Abril", "04", inplace=True)
dfpi["Mês"].replace("Maio", "05", inplace=True)
dfpi["Mês"].replace("Junho", "06", inplace=True)
dfpi["Mês"].replace("Julho", "07", inplace=True)
dfpi["Mês"].replace("Agosto", "08", inplace=True)
dfpi["Mês"].replace("Setembro", "09", inplace=True)
dfpi["Mês"].replace("Outubro", "10", inplace=True)
dfpi["Mês"].replace("Novembro", "11", inplace=True)
dfpi["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfpi['uf']='PI'
dfpi['produto']='Querosene de Aviação'
dfpi['unid']='m3'
dfpi['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 
dfpi.reset_index(inplace=True)

# %%
dfpi=dfpi.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfpi

# %%
# Concatenando as colunas ano e Mês
dfpi['ano_mês'] = dfpi[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfpi.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfpi=dfpi[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfpi.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfpi.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfpi

# %%
# Verificando os tipos

dfpi.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfpi)

# %%
dfpi_pandas = dfpi.copy()

# %% [markdown]
# ##PARANÁ

# %%
# Conector

dfpr = pd.read_csv('/content/PR_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfpr_backup = dfpr.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfpr

# %%
# Replace do Mês para numérico

dfpr["Mês"].replace("Janeiro", "01", inplace=True)
dfpr["Mês"].replace("Fevereiro", "02", inplace=True)
dfpr["Mês"].replace("Março", "03", inplace=True)
dfpr["Mês"].replace("Abril", "04", inplace=True)
dfpr["Mês"].replace("Maio", "05", inplace=True)
dfpr["Mês"].replace("Junho", "06", inplace=True)
dfpr["Mês"].replace("Julho", "07", inplace=True)
dfpr["Mês"].replace("Agosto", "08", inplace=True)
dfpr["Mês"].replace("Setembro", "09", inplace=True)
dfpr["Mês"].replace("Outubro", "10", inplace=True)
dfpr["Mês"].replace("Novembro", "11", inplace=True)
dfpr["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfpr['uf']='PR'
dfpr['produto']='Querosene de Aviação'
dfpr['unid']='m3'
dfpr['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 
dfpr.reset_index(inplace=True)

# %%
dfpr=dfpr.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfpr

# %%
# Concatenando as colunas ano e Mês
dfpr['ano_mês'] = dfpr[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfpr.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfpr=dfpr[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfpr.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfpr.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfpr

# %%
# Verificando os tipos

dfpr.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfpr)

# %%
dfpr_pandas = dfpr.copy()

# %% [markdown]
# ##RIO DE JANEIRO

# %%
# Conector


dfrj = pd.read_csv('/content/RJ_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfrj_backup = dfrj.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfrj

# %%
# Replace do Mês para numérico

dfrj["Mês"].replace("Janeiro", "01", inplace=True)
dfrj["Mês"].replace("Fevereiro", "02", inplace=True)
dfrj["Mês"].replace("Março", "03", inplace=True)
dfrj["Mês"].replace("Abril", "04", inplace=True)
dfrj["Mês"].replace("Maio", "05", inplace=True)
dfrj["Mês"].replace("Junho", "06", inplace=True)
dfrj["Mês"].replace("Julho", "07", inplace=True)
dfrj["Mês"].replace("Agosto", "08", inplace=True)
dfrj["Mês"].replace("Setembro", "09", inplace=True)
dfrj["Mês"].replace("Outubro", "10", inplace=True)
dfrj["Mês"].replace("Novembro", "11", inplace=True)
dfrj["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfrj['uf']='RJ'
dfrj['produto']='Querosene de Aviação'
dfrj['unid']='m3'
dfrj['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume
 
dfrj.reset_index(inplace=True)

# %%
dfrj=dfrj.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfrj

# %%
# Concatenando as colunas ano e Mês
dfrj['ano_mês'] = dfrj[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfrj.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfrj=dfrj[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfrj.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfrj.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfrj

# %%
# Verificando os tipos

dfrj.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfrj)

# %%
dfrj_pandas = dfrj.copy()

# %% [markdown]
# ##RIO GRANDE DO NORTE

# %%
# Conector

dfrn = pd.read_csv('/content/RN_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfrn_backup = dfrn.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfrn

# %%
# Replace do Mês para numérico

dfrn["Mês"].replace("Janeiro", "01", inplace=True)
dfrn["Mês"].replace("Fevereiro", "02", inplace=True)
dfrn["Mês"].replace("Março", "03", inplace=True)
dfrn["Mês"].replace("Abril", "04", inplace=True)
dfrn["Mês"].replace("Maio", "05", inplace=True)
dfrn["Mês"].replace("Junho", "06", inplace=True)
dfrn["Mês"].replace("Julho", "07", inplace=True)
dfrn["Mês"].replace("Agosto", "08", inplace=True)
dfrn["Mês"].replace("Setembro", "09", inplace=True)
dfrn["Mês"].replace("Outubro", "10", inplace=True)
dfrn["Mês"].replace("Novembro", "11", inplace=True)
dfrn["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfrn['uf']='RN'
dfrn['produto']='Querosene de Aviação'
dfrn['unid']='m3'
dfrn['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfrn.reset_index(inplace=True)

# %%
dfrn=dfrn.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfrn

# %%
# Concatenando as colunas ano e Mês
dfrn['ano_mês'] = dfrn[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfrn.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfrn=dfrn[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfrn.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfrn.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfrn

# %%
# Verificando os tipos

dfrn.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfrn)

# %%
dfrn_pandas = dfrn.copy()

# %% [markdown]
# ##RONDÔNIA

# %%
# Conector

dfro = pd.read_csv('/content/RO_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfro_backup = dfro.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfro
# Out:
#           Mês   2000   2001   2002   2003   2004   2005   2006   2007   2008  \
# 0     Janeiro  1.934  1.999  1.355  1.904  1.427  1.344  2.168  1.854  2.027
# 1   Fevereiro  2.175  1.635  1.164  1.498  1.412  1.634  1.764  1.871  1.729
# 2       Março  2.253  2.052  1.189  1.275  1.503  1.867  2.277  1.947  1.745
# 3       Abril  1.939  1.866  1.421  1.298  1.505  1.560  1.834  2.000  1.776
# 4        Maio  2.350  1.703  1.892  1.414  1.609  1.750  2.468  1.467  1.668
# 5       Junho  2.208  1.640  1.177  1.233  1.454  1.982  1.957  1.644  1.620
# 6       Julho  2.772  1.929  1.100  1.247  1.470  2.317  1.934  1.690  2.109
# 7      Agosto  2.086  1.818  1.402  1.115  1.730  2.046  2.059  1.762  1.707
# 8    Setembro  2.043  1.326  1.417  1.294  1.725  2.059  1.875  1.269  1.608
# 9     Outubro  2.263  1.693  1.582  1.413  1.580  2.047  2.045  1.669  1.817
# 10   Novembro  1.791  1.982  1.782  1.271  1.576  1.968  1.876  1.653  1.839
# 11   Dezembro  1.941  1.267  1.662  1.890  1.660  2.190  2.089  2.304  1.526
#
#      2009   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0   2.487  2.219  3.487  3.799  3.418  2.781  2.640  2.849  3.386  2.822
# 1   1.543  1.890  2.759  3.341  2.858  2.527  2.528  2.418  2.136  1.934
# 2   1.966  2.601  3.100  3.562  2.827  2.512  2.544  2.483  2.105  2.411
# 3   2.155  2.510  2.729  3.321  2.973  2.504  2.325  2.091  1.719  2.603
# 4   1.569  2.330  2.771  3.019  2.943  2.347  2.317  1.994  2.016  2.572
# 5   1.811  2.528  2.768  3.116  2.851  2.153  1.934  2.087  2.301  2.239
# 6   1.764  2.846  3.466  3.512  3.013  2.704  2.513  2.317  2.296  2.605
# 7   2.392  2.899  3.232  3.743  2.587  2.571  2.035  2.354  2.366  2.240
# 8   2.004  2.775  3.104  4.418  2.460  2.332  2.279  2.367  2.076  2.402
# 9   2.192  2.865  3.347  3.935  2.443  2.297  2.514  2.059  2.110  2.653
# 10  1.971  2.980  4.189  3.331  2.405  2.358  2.440  1.899  2.433  2.721
# 11  2.255  3.300  4.348  3.726  2.791  2.676  2.728  2.239  2.382  2.860
#
#      2019     2020   2021     2022
# 0   3.305    2.856  2.189    1.990
# 1   2.637    2.584  2.412    1.332
# 2   2.698    2.531  2.958    1.325
# 3   2.632    1.382  2.210    1.045
# 4   2.339    1.082  1.846    1.146
# 5   1.703    1.030  1.446  929.000
# 6   2.092    1.077  1.327      NaN
# 7   1.886  918.000  1.191      NaN
# 8   2.295    1.454  1.996      NaN
# 9   2.487    2.359  2.697      NaN
# 10  1.909    1.559  3.082      NaN
# 11  2.864    2.232  3.304      NaN

# %%
# Replace do Mês para numérico

dfro["Mês"].replace("Janeiro", "01", inplace=True)
dfro["Mês"].replace("Fevereiro", "02", inplace=True)
dfro["Mês"].replace("Março", "03", inplace=True)
dfro["Mês"].replace("Abril", "04", inplace=True)
dfro["Mês"].replace("Maio", "05", inplace=True)
dfro["Mês"].replace("Junho", "06", inplace=True)
dfro["Mês"].replace("Julho", "07", inplace=True)
dfro["Mês"].replace("Agosto", "08", inplace=True)
dfro["Mês"].replace("Setembro", "09", inplace=True)
dfro["Mês"].replace("Outubro", "10", inplace=True)
dfro["Mês"].replace("Novembro", "11", inplace=True)
dfro["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfro['uf']='RO'
dfro['produto']='Querosene de Aviação'
dfro['unid']='m3'
dfro['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfro.reset_index(inplace=True)

# %%
dfro=dfro.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfro

# %%
# Concatenando as colunas ano e Mês
dfro['ano_mês'] = dfro[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfro.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfrs=dfro[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfro.isna().sum()
# Out:
# uf           0
# produto      0
# unid         0
# criado_em    0
# ano          0
# volume       6
# ano_mês      0
# dtype: int64

# %%
# Tratamento das inconsistências

dfro.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)

# %%
# Visão geral da tabela

dfro

# %%
# Verificando os tipos

dfro.dtypes
# Out:
# uf            object
# produto       object
# unid          object
# criado_em     object
# ano           object
# volume       float64
# ano_mês       object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfro)

# %%
dfro_pandas = dfro.copy()

# %% [markdown]
# ##RORAIMA

# %%
# Conector

dfrr = pd.read_csv('/content/RR_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfrr_backup = dfrs.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfrr

# %%
# Replace do Mês para numérico

dfrr["Mês"].replace("Janeiro", "01", inplace=True)
dfrr["Mês"].replace("Fevereiro", "02", inplace=True)
dfrr["Mês"].replace("Março", "03", inplace=True)
dfrr["Mês"].replace("Abril", "04", inplace=True)
dfrr["Mês"].replace("Maio", "05", inplace=True)
dfrr["Mês"].replace("Junho", "06", inplace=True)
dfrr["Mês"].replace("Julho", "07", inplace=True)
dfrr["Mês"].replace("Agosto", "08", inplace=True)
dfrr["Mês"].replace("Setembro", "09", inplace=True)
dfrr["Mês"].replace("Outubro", "10", inplace=True)
dfrr["Mês"].replace("Novembro", "11", inplace=True)
dfrr["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfrr['uf']='RR'
dfrr['produto']='Querosene de Aviação'
dfrr['unid']='m3'
dfrr['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume
 
dfrr.reset_index(inplace=True)

# %%
dfrr=dfrr.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfrr

# %%
# Concatenando as colunas ano e Mês
dfrr['ano_mês'] = dfrr[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfrr.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfrr=dfrr[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfrr.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfrr['volume'] = dfrr['volume'].str.replace('-','NaN')

dfrr.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfrr

# %%
# Verificando os tipos

dfrr.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# dtype: object

# %%
# Convertendo volume para tipo numerico

dfrr['volume'] = pd.to_numeric(dfsp['volume'],errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfrr)

# %%
dfrr_pandas = dfrr.copy()

# %% [markdown]
# ##RIO GRANDE DO SUL

# %%
# Conector

dfrs = pd.read_csv('/content/RS_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfrs_backup = dfrs.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfrs

# %%
# Replace do Mês para numérico

dfrs["Mês"].replace("Janeiro", "01", inplace=True)
dfrs["Mês"].replace("Fevereiro", "02", inplace=True)
dfrs["Mês"].replace("Março", "03", inplace=True)
dfrs["Mês"].replace("Abril", "04", inplace=True)
dfrs["Mês"].replace("Maio", "05", inplace=True)
dfrs["Mês"].replace("Junho", "06", inplace=True)
dfrs["Mês"].replace("Julho", "07", inplace=True)
dfrs["Mês"].replace("Agosto", "08", inplace=True)
dfrs["Mês"].replace("Setembro", "09", inplace=True)
dfrs["Mês"].replace("Outubro", "10", inplace=True)
dfrs["Mês"].replace("Novembro", "11", inplace=True)
dfrs["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfrs['uf']='RS'
dfrs['produto']='Querosene de Aviação'
dfrs['unid']='m3'
dfrs['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfrs.reset_index(inplace=True)

# %%
dfrs=dfrs.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfrs

# %%
# Concatenando as colunas ano e Mês
dfrs['ano_mês'] = dfrs[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfrs.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfrs=dfrs[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfrs.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfrs.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfrs

# %%
# Verificando os tipos

dfrs.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfrs)

# %%
dfrs_pandas = dfrs.copy()

# %% [markdown]
# ##SANTA CATARINA

# %%
# Conector

dfsc = pd.read_csv('/content/SC_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfsc_backup = dfsc.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfsc

# %%
# Replace do Mês para numérico

dfsc["Mês"].replace("Janeiro", "01", inplace=True)
dfsc["Mês"].replace("Fevereiro", "02", inplace=True)
dfsc["Mês"].replace("Março", "03", inplace=True)
dfsc["Mês"].replace("Abril", "04", inplace=True)
dfsc["Mês"].replace("Maio", "05", inplace=True)
dfsc["Mês"].replace("Junho", "06", inplace=True)
dfsc["Mês"].replace("Julho", "07", inplace=True)
dfsc["Mês"].replace("Agosto", "08", inplace=True)
dfsc["Mês"].replace("Setembro", "09", inplace=True)
dfsc["Mês"].replace("Outubro", "10", inplace=True)
dfsc["Mês"].replace("Novembro", "11", inplace=True)
dfsc["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em
dfsc['uf']='SC'
dfsc['produto']='Querosene de Aviação'
dfsc['unid']='m3'
dfsc['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 
dfsc.reset_index(inplace=True)

# %%
dfsc=dfsc.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfsc

# %%
# Concatenando as colunas ano e Mês
dfsc['ano_mês'] = dfsc[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfsc.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfsc=dfsc[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfsc.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfsc.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfsc

# %%
# Verificando os tipos

dfsc.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfsc)

# %%
dfsc_pandas = dfsc.copy()

# %% [markdown]
# ##SERGIPE

# %%
# Conector


dfse = pd.read_csv('/content/SE_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup
dfse_backup = dfse.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfse

# %%
# Replace do Mês para numérico

dfse["Mês"].replace("Janeiro", "01", inplace=True)
dfse["Mês"].replace("Fevereiro", "02", inplace=True)
dfse["Mês"].replace("Março", "03", inplace=True)
dfse["Mês"].replace("Abril", "04", inplace=True)
dfse["Mês"].replace("Maio", "05", inplace=True)
dfse["Mês"].replace("Junho", "06", inplace=True)
dfse["Mês"].replace("Julho", "07", inplace=True)
dfse["Mês"].replace("Agosto", "08", inplace=True)
dfse["Mês"].replace("Setembro", "09", inplace=True)
dfse["Mês"].replace("Outubro", "10", inplace=True)
dfse["Mês"].replace("Novembro", "11", inplace=True)
dfse["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfse['uf']='SE'
dfse['produto']='Querosene de Aviação'
dfse['unid']='m3'
dfse['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfse.reset_index(inplace=True)

# %%
dfse=dfse.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfse

# %%
# Concatenando as colunas ano e Mês

dfse['ano_mês'] = dfse[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfse.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfse=dfse[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfse.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfse['volume'] = dfse['volume'].str.replace('-','NaN')

dfse.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfse

# %%
# Verificando os tipos

dfse.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# dtype: object

# %%
# Convertendo o volume para tipo numerico

dfse['volume'] = pd.to_numeric(dfsp['volume'],errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfse)

# %%
dfse_pandas = dfse.copy()

# %% [markdown]
# ##SÃO PAULO

# %%
# Conector

dfsp = pd.read_csv('/content/SP_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfsp_backup = dfsp.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfsp
# Out:
#           Mês     2000     2001     2002     2003     2004     2005     2006  \
# 0     Janeiro  159.758  200.673  177.801  161.260  158.309  160.452  182.574
# 1   Fevereiro  150.456  178.488  160.697  148.350  149.825  153.869  161.352
# 2       Março  159.417  211.259  179.487  157.830  171.353  181.130  181.777
# 3       Abril  153.012  190.369  180.911  157.453  159.141  166.628  155.241
# 4        Maio  160.820  200.138  174.355  155.913  167.805  172.683  175.058
# 5       Junho  153.801  189.660  158.401  149.815  160.138  171.713  157.907
# 6       Julho  177.349  202.813  165.895  165.981  173.610  182.364  157.730
# 7      Agosto  150.067  197.991  131.993  152.735  169.563  184.632  154.067
# 8    Setembro  157.468  177.766  185.142  160.763  162.576  176.384  154.722
# 9     Outubro  157.884  184.945  156.240  166.621  163.901  174.689  160.684
# 10   Novembro  204.241  172.276  180.606  152.807  167.758  171.355  163.703
# 11   Dezembro  203.091  177.496  153.031  168.163  172.158  180.597  176.081
#
#        2007     2008     2009     2010     2011     2012     2013     2014  \
# 0   174.131  202.200  190.804  214.847  231.209  251.006  230.275  268.150
# 1   157.501  184.575  165.297  186.325  204.832  226.274  202.268  235.011
# 2   179.382  201.276  187.425  213.130  231.195  243.914  246.518  256.689
# 3   166.969  191.628  179.015  197.595  222.480  238.038  230.595  249.301
# 4   174.983  194.318  186.975  210.428  229.274  240.645  235.106  257.821
# 5   170.312  190.313  184.192  208.887  221.593  230.867  230.863  242.698
# 6   182.581  202.739  197.516  227.199  240.371  245.472  244.874  259.816
# 7   179.643  195.383  192.740  219.797  234.210  237.646  249.366  254.099
# 8   173.248  186.202  189.291  213.230  233.697  232.836  237.718  244.233
# 9   189.408  189.361  202.033  223.074  242.411  235.085  250.118  253.245
# 10  184.293  180.016  194.837  220.338  237.935  227.047  244.447  254.159
# 11  201.977  188.072  207.438  231.610  252.838  233.293  264.479  260.667
#
#        2015     2016     2017     2018     2019     2020     2021     2022
# 0   265.494  263.471  250.946  273.016  291.657  291.013  190.277  250.616
# 1   240.292  226.291  211.289  231.672  254.058  261.024  152.798  224.221
# 2   256.379  237.489  233.809  256.462  272.209  206.452  151.184  252.289
# 3   246.836  224.410  222.287  252.961  255.267   45.243  132.700  246.416
# 4   249.575  237.534  229.441  265.596  255.645   56.699  156.279  263.028
# 5   238.984  226.539  227.725  251.234  241.147   72.329  163.846  249.709
# 6   264.895  244.991  248.116  280.456  270.216   90.893  193.637      NaN
# 7   247.464  230.087  241.219  271.211  266.428  103.756  188.540      NaN
# 8   245.890  226.507  228.907  263.265  268.774  118.613  192.612      NaN
# 9   253.184  240.791  246.646  271.115  279.574  146.253  202.957      NaN
# 10  240.777  224.828  241.131  263.883  279.739  159.930  221.560      NaN
# 11  251.884  240.180  262.499  285.411  291.432  184.968  241.737      NaN

# %%
# Replace do Mês para numérico

dfsp["Mês"].replace("Janeiro", "01", inplace=True)
dfsp["Mês"].replace("Fevereiro", "02", inplace=True)
dfsp["Mês"].replace("Março", "03", inplace=True)
dfsp["Mês"].replace("Abril", "04", inplace=True)
dfsp["Mês"].replace("Maio", "05", inplace=True)
dfsp["Mês"].replace("Junho", "06", inplace=True)
dfsp["Mês"].replace("Julho", "07", inplace=True)
dfsp["Mês"].replace("Agosto", "08", inplace=True)
dfsp["Mês"].replace("Setembro", "09", inplace=True)
dfsp["Mês"].replace("Outubro", "10", inplace=True)
dfsp["Mês"].replace("Novembro", "11", inplace=True)
dfsp["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfsp['uf']='SP'
dfsp['produto']='Querosene de Aviação'
dfsp['unid']='m3'
dfsp['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 

dfsp.reset_index(inplace=True)

# %%
dfsp=dfsp.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfsp

# %%
# Concatenando as colunas ano e Mês
dfsp['ano_mês'] = dfsp[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfsp.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfsp=dfsp[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfsp.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
# Tratamento das inconsistências

dfsp.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Visão geral da tabela

dfsp

# %%
# Verificando os tipos

dfsp.dtypes
# Out:
# ano_mês       object
# uf            object
# produto       object
# unid          object
# volume       float64
# criado_em     object
# dtype: object

# %%
# Convertendo volume para tipo numérico

dfsp['volume'] = pd.to_numeric(dfsp['volume'],errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfsp)

# %%
dfsp_pandas = dfsp.copy()

# %% [markdown]
# ##TOCANTINS

# %%
# Conector

dfto = pd.read_csv('/content/TO_QUEROSENE_AVIACAO - Planilha1.csv',sep=',')

# %%
# Backup

dfto_backup = dfto.copy()

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visualização da Tabela

dfto

# %%
# Replace do Mês para numérico

dfto["Mês"].replace("Janeiro", "01", inplace=True)
dfto["Mês"].replace("Fevereiro", "02", inplace=True)
dfto["Mês"].replace("Março", "03", inplace=True)
dfto["Mês"].replace("Abril", "04", inplace=True)
dfto["Mês"].replace("Maio", "05", inplace=True)
dfto["Mês"].replace("Junho", "06", inplace=True)
dfto["Mês"].replace("Julho", "07", inplace=True)
dfto["Mês"].replace("Agosto", "08", inplace=True)
dfto["Mês"].replace("Setembro", "09", inplace=True)
dfto["Mês"].replace("Outubro", "10", inplace=True)
dfto["Mês"].replace("Novembro", "11", inplace=True)
dfto["Mês"].replace("Dezembro", "12", inplace=True)

# %%
# Criação das colunas uf, produto, unid, criado_em

dfto['uf']='TO'
dfto['produto']='Querosene de Aviação'
dfto['unid']='m3'
dfto['criado_em'] ='2022-09-10'

# %%
# Despivotar a tabela em ano e volume 
dfto.reset_index(inplace=True)

# %%
dfto=dfto.melt(id_vars = ['Mês', 'uf', 'produto', 'unid', 'criado_em'], value_vars = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'], var_name='ano', value_name='volume')

# %%
# Visão geral da tabela

dfto

# %%
# Concatenando as colunas ano e Mês
dfto['ano_mês'] = dfto[['ano', 'Mês']].agg('-'.join, axis=1)

# %%
# Eliminando a coluna Mês

dfto.drop(["Mês"], axis=1, inplace=True)

# %%
# Organização da ordem das colunas

dfto=dfto[['ano_mês', 'uf', 'produto', 'unid', 'volume', 'criado_em']]

# %%
# Tratamento de possíveis inconsistências

dfto.isna().sum()
# Out:
# ano_mês      0
# uf           0
# produto      0
# unid         0
# volume       6
# criado_em    0
# dtype: int64

# %%
#usando pandas para trocar nulos e vazios por NA(nulo pandas)

dfto['volume'] = dfto['volume'].str.replace('-','NaN')

dfto.replace(['Na', 'nA', 'na','NA', 'NaN', 'NAN', 'nan', '', ' '],pd.NA,inplace=True)

# %%
# Visão geral da tabela

dfto

# %%
# Verificando os tipos

dfto.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# dtype: object

# %%
# Convertendo para tipo numerico

dfto['volume'] = pd.to_numeric(dfsp['volume'],errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Validação

schema = pa.DataFrameSchema(
    columns = {
        'ano_mês': pa.Column(pa.String, nullable=True),
        'uf': pa.Column(pa.String, nullable = True),
        'produto': pa.Column(pa.String, nullable = True),
        'unid': pa.Column(pa.String, nullable = True),
        'volume': pa.Column(pa.Float, nullable = True),
        'criado_em': pa.Column(pa.String, nullable = True),
                
    }
)
schema.validate(dfto)

# %%
dfto_pandas = dfto.copy()

# %% [markdown]
# # CONCATENAÇÃO DE DATASETS

# %%
teste = 0

# %%
teste = pd.merge(dfac_pandas, dfal_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfap_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfba_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfce_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfdf_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfes_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfgo_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfma_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfmg_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfms_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfmt_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfpa_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfpb_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfpe_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfpi_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfpr_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfrj_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfrn_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfro_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfrr_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfrs_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfsc_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfse_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfsp_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfto_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfam_pandas, how = 'outer')

# %%
# Arquivo foi salvo em formato csv sem o index

teste.to_csv('dataset_querosene_aviacao.csv', index=False)
