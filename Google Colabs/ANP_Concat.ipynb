# %% [markdown]
# ## Instalação do Pandera

# %%
pip install pandera
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ##Instalação PySpark

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ##IMPORTAÇÃO DAS BIBLIOTECAS PANDAS, PANDERA, PYSPARK E FERRAMENTAS

# %%
import pandas as pd
import pandera as pa

from pyspark.sql import SparkSession
from pyspark import SparkConf
import pyspark.sql.functions as F
from pyspark.sql.types import*

# %% [markdown]
# # Datasets

# %% [markdown]
# ##Etanol Hidratado

# %%
# Carregamento do Dataframe Localmente

dfeh = pd.read_csv('/content/dataset_etanol_hidratado.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',7500)

# %%
# Visão geral do dataset

dfeh
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Replace de etanol hidratado para Etanol Hidratado

dfeh['produto'] = dfeh['produto'].apply(lambda x: x.replace('etanol hidratado', 'Etanol Hidratado'))

# %%
# Convertendo as variãveis necessarias para string

dfeh['ano'] = dfeh['ano'].astype(str)

# %%
# Verificando os tipos das colunas

dfeh.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfeh_pandas = dfeh.copy()

# %% [markdown]
# ##Gasolina de Aviação

# %%
# Carregamento do Dataframe Localmente

dfga = pd.read_csv('/content/dataset_gasolina_aviacao.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visão geral do dataset

dfga
# Out:
#       ano_mês  uf              produto unid volume   criado_em  ano
# 0     2000-01  AC  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 1     2000-02  AC  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 2     2000-03  AC  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 3     2000-04  AC  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 4     2000-05  AC  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# ...       ...  ..                  ...  ...    ...         ...  ...
# 7435  2022-08  AM  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 7436  2022-09  AM  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 7437  2022-10  AM  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 7438  2022-11  AM  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
# 7439  2022-12  AM  Gasolina de Aviação   m3    NaN  2022-09-10  NaN
#
# [7440 rows x 7 columns]

# %%
# Convertendo as variãveis necessarias para string

dfga['ano'] = dfga['ano'].astype(str)

# %%
# Verificando os tipos das colunas

dfga.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfga_pandas = dfga.copy()

# %% [markdown]
# ##Gasolina C

# %%
# Carregamento do Dataframe Localmente

dfgc = pd.read_csv('/content/dataset_gasolina_c.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Replace de Gasolina_C para Gasolina C

dfgc['produto'] = dfgc['produto'].apply(lambda x: x.replace('Gasolina_C', 'Gasolina C'))

# %%
# Visão geral do dataset

dfgc
# Out:
#       ano_mês  uf     produto unid  volume   criado_em  ano
# 0     2000-01  AC  Gasolina C   m3   3.066  2022-09-10  NaN
# 1     2000-02  AC  Gasolina C   m3   3.495  2022-09-10  NaN
# 2     2000-03  AC  Gasolina C   m3   2.947  2022-09-10  NaN
# 3     2000-04  AC  Gasolina C   m3   3.024  2022-09-10  NaN
# 4     2000-05  AC  Gasolina C   m3   3.207  2022-09-10  NaN
# ...       ...  ..         ...  ...     ...         ...  ...
# 7447  2022-08  AM  Gasolina C   m3     NaN  2022-09-10  NaN
# 7448  2022-09  AM  Gasolina C   m3     NaN  2022-09-10  NaN
# 7449  2022-10  AM  Gasolina C   m3     NaN  2022-09-10  NaN
# 7450  2022-11  AM  Gasolina C   m3     NaN  2022-09-10  NaN
# 7451  2022-12  AM  Gasolina C   m3     NaN  2022-09-10  NaN
#
# [7452 rows x 7 columns]

# %%
# Convertendo as variáveis necessárias para string

dfgc['volume'] = dfgc['volume'].astype(str)
dfgc['ano'] = dfgc['ano'].astype(str)

# %%
# Verificando os tipos das colunas

dfgc.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfgc_pandas = dfgc.copy()

# %% [markdown]
# ##GLP

# %%
# Carregamento do Dataframe Localmente

dfglp = pd.read_csv('/content/dataset_glp.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visão geral do dataset

dfglp
# Out:
#       ano_mês  uf produto unid  volume   criado_em  ano
# 0     2000-01  AC     GLP   m3   1.959  2022-09-10  NaN
# 1     2000-02  AC     GLP   m3   2.216  2022-09-10  NaN
# 2     2000-03  AC     GLP   m3   2.305  2022-09-10  NaN
# 3     2000-04  AC     GLP   m3   2.190  2022-09-10  NaN
# 4     2000-05  AC     GLP   m3   2.267  2022-09-10  NaN
# ...       ...  ..     ...  ...     ...         ...  ...
# 7435  2022-08  AM     GLP   m3     NaN  2022-09-10  NaN
# 7436  2022-09  AM     GLP   m3     NaN  2022-09-10  NaN
# 7437  2022-10  AM     GLP   m3     NaN  2022-09-10  NaN
# 7438  2022-11  AM     GLP   m3     NaN  2022-09-10  NaN
# 7439  2022-12  AM     GLP   m3     NaN  2022-09-10  NaN
#
# [7440 rows x 7 columns]

# %%
# Convertendo as variaveis necessárias para string

dfglp['ano'] = dfglp['ano'].astype(str)
dfglp['volume'] = dfglp['volume'].astype(str)

# %%
# Verificando os tipos das colunas

dfglp.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfglp_pandas = dfglp.copy()

# %% [markdown]
# ##Óleo Combustível

# %%
# Carregamento do Dataframe Localmente

dfoc = pd.read_csv('/content/dataset_oleo_combustivel.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visão geral do dataset

dfoc
# Out:
#       ano_mês  uf           produto unid    volume   criado_em  ano
# 0     2003-01  AC  Óleo Combustível   m3    NaN     2022-09-10  NaN
# 1     2003-02  AC  Óleo Combustível   m3    NaN     2022-09-10  NaN
# 2     2003-03  AC  Óleo Combustível   m3      169   2022-09-10  NaN
# 3     2003-04  AC  Óleo Combustível   m3    NaN     2022-09-10  NaN
# 4     2003-05  AC  Óleo Combustível   m3    NaN     2022-09-10  NaN
# ...       ...  ..               ...  ...       ...         ...  ...
# 6859  2022-08  AM  Óleo Combustível   m3       NaN  2022-09-10  NaN
# 6860  2022-09  AM  Óleo Combustível   m3       NaN  2022-09-10  NaN
# 6861  2022-10  AM  Óleo Combustível   m3       NaN  2022-09-10  NaN
# 6862  2022-11  AM  Óleo Combustível   m3       NaN  2022-09-10  NaN
# 6863  2022-12  AM  Óleo Combustível   m3       NaN  2022-09-10  NaN
#
# [6864 rows x 7 columns]

# %%
# Convertendo as variáveis necessárias para string

dfoc['ano'] = dfoc['ano'].astype(str)

# %%
# Verificando os tipos das colunas

dfoc.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfoc_pandas = dfoc.copy()

# %% [markdown]
# ##Óleo Diesel

# %%
# Carregamento do Dataframe Localmente

dfod = pd.read_csv('/content/dataset_oleo_diesel.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Replace da coluna criado_em

dfod['criado_em'] = dfod['criado_em'].apply(lambda x: x.replace('2022-09-10', '2022-09-11'))

# %%
# Convertendo as variáveis necessárias para string

dfod['ano'] = dfod['ano'].astype(str)
dfod['volume'] = dfod['volume'].astype(str)

# %%
# Visão geral do dataset

dfod
# Out:
#       ano_mês  uf      produto unid  volume   criado_em  ano
# 0     2000-01  AC  Óleo Diesel   m3  18.025  2022-09-11  nan
# 1     2000-02  AC  Óleo Diesel   m3  18.336  2022-09-11  nan
# 2     2000-03  AC  Óleo Diesel   m3  16.654  2022-09-11  nan
# 3     2000-04  AC  Óleo Diesel   m3  15.146  2022-09-11  nan
# 4     2000-05  AC  Óleo Diesel   m3  18.681  2022-09-11  nan
# ...       ...  ..          ...  ...     ...         ...  ...
# 7447  2022-08  AM  Óleo Diesel   m3     nan  2022-09-11  nan
# 7448  2022-09  AM  Óleo Diesel   m3     nan  2022-09-11  nan
# 7449  2022-10  AM  Óleo Diesel   m3     nan  2022-09-11  nan
# 7450  2022-11  AM  Óleo Diesel   m3     nan  2022-09-11  nan
# 7451  2022-12  AM  Óleo Diesel   m3     nan  2022-09-11  nan
#
# [7452 rows x 7 columns]

# %%
# Verificando os tipos das colunas

dfod.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfod_pandas = dfod.copy()

# %% [markdown]
# ##Querosene de Aviação

# %%
# Carregamento do Dataframe Localmente

dfqa = pd.read_csv('/content/dataset_querosene_aviacao.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Visão geral do dataset

dfqa
# Out:
#       ano_mês  uf               produto unid   volume   criado_em  ano
# 0     2000-01  AC  Querosene de Aviação   m3    1.155  2022-09-10  NaN
# 1     2000-02  AC  Querosene de Aviação   m3    1.251  2022-09-10  NaN
# 2     2000-03  AC  Querosene de Aviação   m3  813.000  2022-09-10  NaN
# 3     2000-04  AC  Querosene de Aviação   m3  702.000  2022-09-10  NaN
# 4     2000-05  AC  Querosene de Aviação   m3  964.000  2022-09-10  NaN
# ...       ...  ..                   ...  ...      ...         ...  ...
# 7435  2022-08  AM  Querosene de Aviação   m3      NaN  2022-09-10  NaN
# 7436  2022-09  AM  Querosene de Aviação   m3      NaN  2022-09-10  NaN
# 7437  2022-10  AM  Querosene de Aviação   m3      NaN  2022-09-10  NaN
# 7438  2022-11  AM  Querosene de Aviação   m3      NaN  2022-09-10  NaN
# 7439  2022-12  AM  Querosene de Aviação   m3      NaN  2022-09-10  NaN
#
# [7440 rows x 7 columns]

# %%
# Convertendo as variáveis necessárias para string

dfqa['ano'] = dfqa['ano'].astype(str)
dfqa['volume'] = dfqa['volume'].astype(str)

# %%
# Verificando os tipos das colunas

dfqa.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfqa_pandas = dfqa.copy()

# %% [markdown]
# ##Querosene Iluminante

# %%
# Carregamento do Dataframe Localmente

dfqi = pd.read_csv('/content/dataset_querosene_iluminante.csv',sep=',')

# %%
# Configurando a quantidade de linhas máximas mostradas em tela

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
# Replace da coluna criado_em

dfqi['criado_em'] = dfqi['criado_em'].apply(lambda x: x.replace('2022-09-10', '2022-09-11'))
dfqi['produto'] = dfqi['produto'].apply(lambda x: x.replace('Querosene_Iluminante', 'Querosene Iluminante'))

# %%
# Visão geral do dataset

dfqi
# Out:
#       ano_mês  uf               produto unid volume   criado_em  ano
# 0     2000-01  SP  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 1     2000-02  SP  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 2     2000-03  SP  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 3     2000-04  SP  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 4     2000-05  SP  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# ...       ...  ..                   ...  ...    ...         ...  ...
# 4243  2022-08  BA  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 4244  2022-09  BA  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 4245  2022-10  BA  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 4246  2022-11  BA  Querosene Iluminante   m3    NaN  2022-09-11  NaN
# 4247  2022-12  BA  Querosene Iluminante   m3    NaN  2022-09-11  NaN
#
# [4248 rows x 7 columns]

# %%
# Convertendo as variáveis necessárias para string

dfqi['ano'] = dfqi['ano'].astype(str)

# %%
# Verificando os tipos das colunas

dfqi.dtypes
# Out:
# ano_mês      object
# uf           object
# produto      object
# unid         object
# volume       object
# criado_em    object
# ano          object
# dtype: object

# %%
# Backup

dfqi_pandas = dfqi.copy()

# %% [markdown]
# ## CONCATENAÇÃO DE DATASETS

# %%
teste = pd.merge(dfeh_pandas, dfga_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfgc_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfglp_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfoc_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfod_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfqa_pandas, how = 'outer')

# %%
teste = pd.merge(teste, dfqi_pandas, how = 'outer')

# %%
# Arquivo foi salvo em formato csv sem o index

teste.to_csv('dataset_derivados_pandas.csv', index=False)

# %% [markdown]
# # Analise do Dataset Final e Tratamento com PySpark

# %%
# Carregamento do Dataframe Localmente

dfddpandas = pd.read_csv('/content/dataset_derivados_pandas.csv',sep=',')

# %%
# Análise dos dados da coluna volume
listavolume = []

for i in dfddpandas['volume']:
  listavolume.append(i)

# %%
listavolume
# Out:
# ['501.0',
#  '454.0',
#  '676.0',
#  '678.0',
#  '1.467',
#  '351.0',
#  '451.0',
#  '603.0',
#  '531.0',
#  '573.0',
#  '305.0',
#  '566.0',
#  '431.0',
#  '387.0',
#  '428.0',
#  '401.0',
#  '427.0',
#  '446.0',
#  '402.0',
#  '476.0',
#  '427.0',
#  '304.0',
#  '365.0',
#  '277.0',
#  '310.0',
#  '306.0',
#  '395.0',
#  '447.0',
#  '411.0',
#  '362.0',
#  '379.0',
#  '407.0',
#  '458.0',
#  '450.0',
#  '288.0',
#  '215.0',
#  '250.0',
#  '316.0',
#  '350.0',
#  '255.0',
#  '253.0',
#  '227.0',
#  '376.0',
#  '293.0',
#  '373.0',
#  '319.0',
#  '294.0',
#  '347.0',
#  '297.0',
#  '296.0',
#  '282.0',
#  '254.0',
#  '337.0',
#  '257.0',
#  '338.0',
#  '356.0',
#  '332.0',
#  '327.0',
#  '318.0',
#  '359.0',
#  '303.0',
#  '265.0',
#  '260.0',
#  '301.0',
#  '312.0',
#  '342.0',
#  '311.0',
#  '367.0',
#  '361.0',
#  '381.0',
#  '342.0',
#  '454.0',
#  '344.0',
#  '318.0',
#  '293.0',
#  '243.0',
#  '286.0',
#  '304.0',
#  '357.0',
#  '380.0',
#  '378.0',
#  '362.0',
#  '407.0',
# ...

# %% [markdown]
# #PySpark

# %%
# Construção do Sparksession
spark = ( 
    SparkSession.builder
                .master("local")
                .appName("dataset_derivados_pandas")
                .config("spark.ui.port", "4050")
                .getOrCreate() 
        )

# %%
# StructType
esquema = (
    StructType([
        
        StructField('ano_mês', DateType()),
        StructField('uf', StringType()),
        StructField('produto', StringType()),
        StructField('unid', StringType()),
        StructField('volume', DoubleType()),
        StructField('criado_em', TimestampType())
                
    ]))

# %%
# Ao final do arquivo csv, foi adicionado o schema do dataframe construído no StructType

dfddp = ( spark.read.format("csv")
                  .option("header", "true")
                  .option("inferschema", "true")
                  .option("delimiter", ",")
                  .load('/content/dataset_derivados_pandas.csv', schema = esquema)
)

# %%
# Análise dos tipos das colunas

dfddp.printSchema()
# Out:
# root
#  |-- ano_mês: date (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- unid: string (nullable = true)
#  |-- volume: double (nullable = true)
#  |-- criado_em: timestamp (nullable = true)

# %%
# Criando a lista de Colunas Novas

colunasNovas = []

for i in dfddp.columns:
  colunasNovas.append(i)
  print(i)
# Out:
# ano_mês
# uf
# produto
# unid
# volume
# criado_em

# %%
# Verificando inconsistencias por valores unicos no topo e final das colunas

for i in range(len(colunasNovas)):
  dfddp.select(F.col(colunasNovas[i])).distinct().orderBy(colunasNovas[i], ascending=True).show(10)
# Out:
# +----------+
# |   ano_mês|
# +----------+
# |2000-01-01|
# |2000-02-01|
# |2000-03-01|
# |2000-04-01|
# |2000-05-01|
# |2000-06-01|
# |2000-07-01|
# |2000-08-01|
# |2000-09-01|
# |2000-10-01|
# +----------+
# only showing top 10 rows
#
# +---+
# | uf|
# +---+
# | AC|
# | AL|
# | AM|
# | AP|
# | BA|
# | CE|
# | DF|
# | ES|
# | GO|
# | MA|
# +---+
# only showing top 10 rows
#
# +--------------------+
# |             produto|
# +--------------------+
# |    Etanol Hidratado|
# |                 GLP|
# |          Gasolina C|
# | Gasolina de Aviação|
# |Querosene Iluminante|
# |Querosene de Aviação|
# |    Óleo Combustível|
# |         Óleo Diesel|
# +--------------------+
#
# +----+
# |unid|
# +----+
# |  m3|
# +----+
#
# +------+
# |volume|
# +------+
# |  null|
# |   0.0|
# |   1.0|
# | 1.001|
# | 1.002|
# | 1.003|
# | 1.004|
# | 1.005|
# | 1.006|
# | 1.007|
# +------+
# only showing top 10 rows
#
# +-------------------+
# |          criado_em|
# +-------------------+
# ...

# %%
# Verificando inconsistencias por valores unicos no topo e final das colunas

for i in range(len(colunasNovas)):
  dfddp.select(F.col(colunasNovas[i])).distinct().orderBy(colunasNovas[i], ascending=False).show(10)
# Out:
# +----------+
# |   ano_mês|
# +----------+
# |2022-12-01|
# |2022-11-01|
# |2022-10-01|
# |2022-09-01|
# |2022-08-01|
# |2022-07-01|
# |2022-06-01|
# |2022-05-01|
# |2022-04-01|
# |2022-03-01|
# +----------+
# only showing top 10 rows
#
# +---+
# | uf|
# +---+
# | TO|
# | SP|
# | SE|
# | SC|
# | RS|
# | RR|
# | RO|
# | RN|
# | RJ|
# | PR|
# +---+
# only showing top 10 rows
#
# +--------------------+
# |             produto|
# +--------------------+
# |         Óleo Diesel|
# |    Óleo Combustível|
# |Querosene de Aviação|
# |Querosene Iluminante|
# | Gasolina de Aviação|
# |          Gasolina C|
# |                 GLP|
# |    Etanol Hidratado|
# +--------------------+
#
# +----+
# |unid|
# +----+
# |  m3|
# +----+
#
# +-------+
# | volume|
# +-------+
# |    NaN|
# |  999.0|
# |  998.0|
# |997.923|
# |997.848|
# |997.237|
# |  997.0|
# |  996.0|
# |995.166|
# |  995.0|
# +-------+
# only showing top 10 rows
#
# +-------------------+
# |          criado_em|
# +-------------------+
# ...

# %%
# Tratamento de inconsistencias na coluna volume

dfddp = dfddp.replace(str('nan'), None)

# %%
dfddp = dfddp.replace(str('null'), None)

# %%
# Eliminando todos os na

dfddp=dfddp.dropna()

# %%
# Contagem das inconsistencias

dfddp.where(F.col('volume').isNull()).count()
# Out:
# 0

# %%
dfddp.show()
# Out:
# +----------+---+----------------+----+------+-------------------+
# |   ano_mês| uf|         produto|unid|volume|          criado_em|
# +----------+---+----------------+----+------+-------------------+
# |2000-01-01| AC|Etanol Hidratado|  m3| 501.0|2022-09-10 00:00:00|
# |2000-02-01| AC|Etanol Hidratado|  m3| 454.0|2022-09-10 00:00:00|
# |2000-03-01| AC|Etanol Hidratado|  m3| 676.0|2022-09-10 00:00:00|
# |2000-04-01| AC|Etanol Hidratado|  m3| 678.0|2022-09-10 00:00:00|
# |2000-05-01| AC|Etanol Hidratado|  m3| 1.467|2022-09-10 00:00:00|
# |2000-06-01| AC|Etanol Hidratado|  m3| 351.0|2022-09-10 00:00:00|
# |2000-07-01| AC|Etanol Hidratado|  m3| 451.0|2022-09-10 00:00:00|
# |2000-08-01| AC|Etanol Hidratado|  m3| 603.0|2022-09-10 00:00:00|
# |2000-09-01| AC|Etanol Hidratado|  m3| 531.0|2022-09-10 00:00:00|
# |2000-10-01| AC|Etanol Hidratado|  m3| 573.0|2022-09-10 00:00:00|
# |2000-11-01| AC|Etanol Hidratado|  m3| 305.0|2022-09-10 00:00:00|
# ...

# %%
dfddp.dtypes
# Out:
# [('ano_mês', 'date'),
#  ('uf', 'string'),
#  ('produto', 'string'),
#  ('unid', 'string'),
#  ('volume', 'double'),
#  ('criado_em', 'timestamp')]

# %%
# Salvar o dataset em 
dfddp.write.csv('dataset_derivados_anp.csv')

# %% [markdown]
# # Tratamento do Dataset referente ao Diesel

# %%
# Carregamento do Dataframe Localmente

dfdieselpandas = pd.read_csv('/content/dataset_oleo_diesel.csv',sep=',')

# %%
# Análise dos dados da coluna volume

listavolumed = []

for i in dfdieselpandas['volume']:
  listavolumed.append(i)

# %%
listavolumed

# %%
# Construção do Sparksession
spark = ( 
    SparkSession.builder
                .master("local")
                .appName("dataset_diesel_pandas")
                .config("spark.ui.port", "4050")
                .getOrCreate() 
        )

# %%
# StructType
esquema = (
    StructType([
        
        StructField('ano_mês', DateType()),
        StructField('uf', StringType()),
        StructField('produto', StringType()),
        StructField('unid', StringType()),
        StructField('volume', DoubleType()),
        StructField('criado_em', TimestampType())
                
    ]))

# %%
# Ao final do arquivo csv, foi adicionado o schema do dataframe construído no StructType

dfdiesel = ( spark.read.format("csv")
                  .option("header", "true")
                  .option("inferschema", "true")
                  .option("delimiter", ",")
                  .load('/content/dataset_oleo_diesel.csv', schema = esquema)
)

# %%
# Análise dos tipos das colunas

dfdiesel.printSchema()

# %%
# Criando a lista de Colunas Novas

colunasNovas = []

for i in dfdiesel.columns:
  colunasNovas.append(i)
  print(i)
# Out:
# ano_mês
# uf
# produto
# unid
# volume
# criado_em

# %%
# Verificando inconsistencias por valores unicos no topo e final das colunas

for i in range(len(colunasNovas)):
  dfdiesel.select(F.col(colunasNovas[i])).distinct().orderBy(colunasNovas[i], ascending=True).show(10)

# %%
# Verificando inconsistencias por valores unicos no topo e final das colunas

for i in range(len(colunasNovas)):
  dfdiesel.select(F.col(colunasNovas[i])).distinct().orderBy(colunasNovas[i], ascending=False).show(10)
# Out:
# +----------+
# |   ano_mês|
# +----------+
# |2022-12-01|
# |2022-11-01|
# |2022-10-01|
# |2022-09-01|
# |2022-08-01|
# |2022-07-01|
# |2022-06-01|
# |2022-05-01|
# |2022-04-01|
# |2022-03-01|
# +----------+
# only showing top 10 rows
#
# +---+
# | uf|
# +---+
# | TO|
# | SP|
# | SE|
# | SC|
# | RS|
# | RR|
# | RO|
# | RN|
# | RJ|
# | PR|
# +---+
# only showing top 10 rows
#
# +-----------+
# |    produto|
# +-----------+
# |Óleo Diesel|
# +-----------+
#
# +----+
# |unid|
# +----+
# |  m3|
# +----+
#
# +-------+
# | volume|
# +-------+
# |997.923|
# |997.848|
# |997.237|
# |992.246|
# |989.328|
# |986.825|
# |985.268|
# | 982.66|
# | 982.12|
# |977.727|
# +-------+
# only showing top 10 rows
#
# +-------------------+
# |          criado_em|
# +-------------------+
# |2022-09-11 00:00:00|
# +-------------------+

# %%
# Contagem das inconsistencias

dfdiesel.where(F.col('volume').isNull()).count()
# Out:
# 0

# %%
# Tratamento de inconsistencias na coluna volume

dfdiesel = dfdiesel.replace(str('nan'), None)

# %%
dfdiesel = dfdiesel.replace(str('null'), None)

# %%
# Eliminando todos os na

dfdiesel=dfdiesel.dropna()

# %%
dfdiesel.show()
# Out:
# +----------+---+-----------+----+------+-------------------+
# |   ano_mês| uf|    produto|unid|volume|          criado_em|
# +----------+---+-----------+----+------+-------------------+
# |2000-01-01| AC|Óleo Diesel|  m3|18.025|2022-09-11 00:00:00|
# |2000-02-01| AC|Óleo Diesel|  m3|18.336|2022-09-11 00:00:00|
# |2000-03-01| AC|Óleo Diesel|  m3|16.654|2022-09-11 00:00:00|
# |2000-04-01| AC|Óleo Diesel|  m3|15.146|2022-09-11 00:00:00|
# |2000-05-01| AC|Óleo Diesel|  m3|18.681|2022-09-11 00:00:00|
# |2000-06-01| AC|Óleo Diesel|  m3|17.949|2022-09-11 00:00:00|
# |2000-07-01| AC|Óleo Diesel|  m3|17.466|2022-09-11 00:00:00|
# |2000-08-01| AC|Óleo Diesel|  m3|19.174|2022-09-11 00:00:00|
# |2000-09-01| AC|Óleo Diesel|  m3|19.505|2022-09-11 00:00:00|
# |2000-10-01| AC|Óleo Diesel|  m3| 19.96|2022-09-11 00:00:00|
# |2000-11-01| AC|Óleo Diesel|  m3|19.349|2022-09-11 00:00:00|
# |2000-12-01| AC|Óleo Diesel|  m3|18.796|2022-09-11 00:00:00|
# ...

# %%
# Salvando arquivo em csv

dfdiesel.write.csv('diesel.csv')
